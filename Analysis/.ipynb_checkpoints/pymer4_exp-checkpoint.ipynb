# %%
import os

os.environ["R_HOME"] = "/home/ssimha/miniconda3/envs/ospmef/lib/R"
os.environ["PATH"] = "/home/ssimha/miniconda3/envs/ospmef/bin:" + os.environ.get("PATH","")

# sanity checks
import subprocess, sys
print("Python:", sys.executable)
print("R:", subprocess.check_output(["which", "R"], text=True).strip())
print("RHOME:", subprocess.check_output(["R", "RHOME"], text=True).strip())
# Out:
# Python: /home/ssimha/miniconda3/envs/ospmef/bin/python3
# R: /home/ssimha/miniconda3/envs/ospmef/bin/R
# RHOME: /home/ssimha/miniconda3/envs/ospmef/lib/R

# %%
import pymer4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pymer4
#
# File ~/miniconda3/envs/ospmef/lib/python3.12/site-packages/pymer4/__init__.py:2
#       1 # ruff: noqa
# ----> 2 from .io import load_dataset, load_model, save_model
#       3 from .expressions import *
#       4 from .rfuncs import *
#
# File ~/miniconda3/envs/ospmef/lib/python3.12/site-packages/pymer4/io.py:5
#       3 import polars as pl
#       4 import os
# ----> 5 from rpy2.robjects.packages import importr
#       6 from joblib import dump, load
#       7 from importlib import resources
#
# File ~/miniconda3/envs/ospmef/lib/python3.12/site-packages/rpy2/robjects/__init__.py:18
#      15 import rpy2.rinterface as rinterface
#      16 import rpy2.rlike.container as rlc
# ---> 18 from rpy2.robjects.robject import RObjectMixin, RObject
#      19 import rpy2.robjects.functions
# ...

# %%
from pymer4.models import glmer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pymer4.models import glmer
#
# File ~/miniconda3/envs/ospmef/lib/python3.12/site-packages/pymer4/__init__.py:2
#       1 # ruff: noqa
# ----> 2 from .io import load_dataset, load_model, save_model
#       3 from .expressions import *
#       4 from .rfuncs import *
#
# File ~/miniconda3/envs/ospmef/lib/python3.12/site-packages/pymer4/io.py:5
#       3 import polars as pl
#       4 import os
# ----> 5 from rpy2.robjects.packages import importr
#       6 from joblib import dump, load
#       7 from importlib import resources
#
# File ~/miniconda3/envs/ospmef/lib/python3.12/site-packages/rpy2/robjects/__init__.py:18
#      15 import rpy2.rinterface as rinterface
#      16 import rpy2.rlike.container as rlc
# ---> 18 from rpy2.robjects.robject import RObjectMixin, RObject
# ...

# %%
import polars as pl, polars.selectors as cs
from polars import col
import seaborn as sns
from pymer4 import load_dataset
