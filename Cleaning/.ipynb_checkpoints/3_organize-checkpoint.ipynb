# %% [markdown]
# # Organize
# 1. Create grid of 12h
# 2. Add mean and last known

# %%
import pandas as pd
import numpy as np
import json

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ltm = pd.read_parquet("../Dataset/mimic-iv/from_pipeline/ltm.parquet")

# %%
ltm.stay_id.isna().sum()
# Out:
# 0

# %%
ltm
# Out:
#                   stay_id            time  value  \
# 0         mimic4-39243046 0 days 14:10:00   95.0
# 1         mimic4-37320744 0 days 09:56:00   96.0
# 2         mimic4-36514617 2 days 22:59:27    4.0
# 3         mimic4-31332266 2 days 05:35:50   98.0
# 4         mimic4-37934184 1 days 01:30:00   96.0
# ...                   ...             ...    ...
# 78385965  mimic4-35762379 0 days 03:52:05   95.0
# 78385966  mimic4-39395470 0 days 11:09:19   98.0
# 78385967  mimic4-30374531 4 days 05:51:15  119.0
# 78385968  mimic4-38572808 5 days 04:33:51   81.0
# 78385969  mimic4-38942593 0 days 21:32:00   13.0
#
#                                   variable subject_id  raw_age  sex  \
# 0              O2_pulseoxymetry_saturation   10064390     74.0  1.0
# 1              O2_pulseoxymetry_saturation   10063991     35.0  1.0
# 2                 glasgow_coma_score_motor   10066209     82.0  0.0
# 3              O2_pulseoxymetry_saturation   10063848     75.0  0.0
# 4              O2_pulseoxymetry_saturation   10066489     91.0  0.0
# ...                                    ...        ...      ...  ...
# 78385965  invasive_systolic_blood_pressure   10055729     62.0  1.0
# 78385966  invasive_systolic_blood_pressure   10055828     75.0  1.0
# 78385967  invasive_systolic_blood_pressure   10056223     48.0  1.0
# 78385968                        heart_rate   10057482     76.0  0.0
# 78385969                  respiratory_rate   10055694     58.0  0.0
#
#           raw_height  raw_weight         unit_type     origin  \
# 0             175.13     84.6000          Surgical  Emergency
# 1                NaN     58.0000      Neurological      Other
# 2             149.93     75.3186  Medical-Surgical  Emergency
# 3             149.93     85.5000          Surgical  Emergency
# 4                NaN     56.8000          Surgical  Emergency
# ...              ...         ...               ...        ...
# 78385965      185.21    132.7000          Surgical      Other
# 78385966      165.05     74.0020           Cardiac      Other
# 78385967      165.05    104.5000          Surgical      Other
# 78385968      152.20     55.6000           Medical      Other
# 78385969      170.09     70.5062  Medical-Surgical  Emergency
#
#                       los              intime             outtime  \
# 0         6 days 03:08:32 2137-11-16 15:50:00 2137-11-22 18:58:32
# 1         4 days 00:34:50 2148-01-26 18:04:00 2148-01-30 18:38:50
# 2         3 days 16:16:17 2121-07-04 01:00:33 2121-07-07 17:16:50
# 3         2 days 16:17:38 2177-07-27 18:24:10 2177-07-30 10:41:48
# 4         1 days 21:48:43 2141-07-19 18:30:00 2141-07-21 16:18:43
# ...                   ...                 ...                 ...
# 78385965 10 days 20:52:52 2141-11-30 00:07:55 2141-12-10 21:00:47
# 78385966  0 days 23:24:32 2146-11-30 12:50:41 2146-12-01 12:15:13
# 78385967  5 days 00:59:08 2122-09-23 15:08:45 2122-09-28 16:07:53
# 78385968  6 days 15:02:52 2145-07-29 00:26:09 2145-08-04 15:29:01
# 78385969  3 days 04:01:55 2120-10-12 13:28:00 2120-10-15 17:29:55
#
#          death_time_from_intime  icu_mortality
# 0                           NaT              0
# 1                           NaT              0
# 2             160 days 22:59:27              0
# 3                           NaT              0
# 4                           NaT              0
# ...                         ...            ...
# 78385965                    NaT              0
# 78385966                    NaT              0
# 78385967                    NaT              0
# 78385968       28 days 23:33:51              0
# 78385969      568 days 10:32:00              0
#
# [78385970 rows x 16 columns]

# %%
ltm.loc[ltm.stay_id=="mimic4-34155256"].sort_values("time").head(5)
# Out:
#                   stay_id            time       value  \
# 2275631   mimic4-34155256 0 days 00:07:00   36.388889
# 69861461  mimic4-34155256 0 days 00:18:00   61.000000
# 50361571  mimic4-34155256 0 days 00:18:00   47.000000
# 2276401   mimic4-34155256 0 days 00:18:00  109.000000
# 69861957  mimic4-34155256 0 days 00:18:00  108.000000
#
#                                       variable subject_id  raw_age  sex  \
# 2275631                            temperature   10087623     48.0  0.0
# 69861461       noninvasive_mean_blood_pressure   10087623     48.0  0.0
# 50361571  noninvasive_diastolic_blood_pressure   10087623     48.0  0.0
# 2276401                             heart_rate   10087623     48.0  0.0
# 69861957   noninvasive_systolic_blood_pressure   10087623     48.0  0.0
#
#           raw_height  raw_weight unit_type     origin                     los  \
# 2275631       154.97        73.0   Medical  Emergency 10 days 20:49:44.999999
# 69861461      154.97        73.0   Medical  Emergency 10 days 20:49:44.999999
# 50361571      154.97        73.0   Medical  Emergency 10 days 20:49:44.999999
# 2276401       154.97        73.0   Medical  Emergency 10 days 20:49:44.999999
# 69861957      154.97        73.0   Medical  Emergency 10 days 20:49:44.999999
#
#                       intime             outtime death_time_from_intime  \
# 2275631  2129-03-23 16:53:00 2129-04-03 13:42:45       10 days 07:07:00
# 69861461 2129-03-23 16:53:00 2129-04-03 13:42:45       10 days 07:07:00
# 50361571 2129-03-23 16:53:00 2129-04-03 13:42:45       10 days 07:07:00
# 2276401  2129-03-23 16:53:00 2129-04-03 13:42:45       10 days 07:07:00
# 69861957 2129-03-23 16:53:00 2129-04-03 13:42:45       10 days 07:07:00
#
#           icu_mortality
# 2275631               1
# 69861461              1
# 50361571              1
# 2276401               1
# 69861957              1

# %%
# Columns that do NOT change over time (baseline variables)
baseline_cols = [
    "stay_id", "subject_id", "raw_age", "sex", "raw_height", "raw_weight",
    "unit_type", "origin", "los", "intime", "outtime", "death_time_from_intime", "icu_mortality"
]

# Pivot: variables → columns, values → entries
ltm_wide = (
    ltm
    .pivot_table(
        index=["stay_id", "time"],   # one row per (stay_id, time)
        columns="variable",          # each variable becomes a new column
        values="value",              # values fill the new columns
        aggfunc="first"              # safe if no duplicates
    )
    .reset_index()
)

# Merge baseline columns back (they are constant per stay_id)
ltm_wide = ltm_wide.merge(
    ltm[baseline_cols].drop_duplicates("stay_id"),
    on="stay_id",
    how="left"
)

# %%
ltm_wide
# Out:
#                   stay_id            time  FiO2  O2_arterial_saturation  \
# 0         mimic4-30000153 0 days 00:03:00   NaN                     NaN
# 1         mimic4-30000153 0 days 00:16:00  50.0                     NaN
# 2         mimic4-30000153 0 days 00:36:00   NaN                     NaN
# 3         mimic4-30000153 0 days 00:51:00   NaN                     NaN
# 4         mimic4-30000153 0 days 01:07:00   NaN                     NaN
# ...                   ...             ...   ...                     ...
# 14878323  mimic4-39999858 3 days 16:24:00   NaN                     NaN
# 14878324  mimic4-39999858 3 days 16:27:00   NaN                     NaN
# 14878325  mimic4-39999858 3 days 17:24:00   NaN                     NaN
# 14878326  mimic4-39999858 3 days 18:24:00   NaN                     NaN
# 14878327  mimic4-39999858 3 days 19:24:00   NaN                     NaN
#
#           O2_pulseoxymetry_saturation  PEEP  PTT  alanine_aminotransferase  \
# 0                                 NaN   NaN  NaN                       NaN
# 1                                 NaN   NaN  NaN                       NaN
# 2                                 NaN   NaN  NaN                       NaN
# 3                               100.0   NaN  NaN                       NaN
# 4                                 NaN   NaN  NaN                       NaN
# ...                               ...   ...  ...                       ...
# 14878323                         95.0   NaN  NaN                       NaN
# 14878324                          NaN   NaN  NaN                       NaN
# 14878325                         94.0   NaN  NaN                       NaN
# 14878326                         88.0   NaN  NaN                       NaN
# 14878327                         90.0   NaN  NaN                       NaN
#
#           albumin  alkaline_phosphatase  ...  sex  raw_height  raw_weight  \
# 0             NaN                   NaN  ...  1.0         NaN        73.0
# 1             NaN                   NaN  ...  1.0         NaN        73.0
# 2             NaN                   NaN  ...  1.0         NaN        73.0
# 3             NaN                   NaN  ...  1.0         NaN        73.0
# 4             NaN                   NaN  ...  1.0         NaN        73.0
# ...           ...                   ...  ...  ...         ...         ...
# 14878323      NaN                   NaN  ...  1.0         NaN       123.8
# 14878324      NaN                   NaN  ...  1.0         NaN       123.8
# 14878325      NaN                   NaN  ...  1.0         NaN       123.8
# 14878326      NaN                   NaN  ...  1.0         NaN       123.8
# 14878327      NaN                   NaN  ...  1.0         NaN       123.8
#
#                  unit_type        origin             los              intime  \
# 0                   Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 1                   Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 2                   Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 3                   Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 4                   Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# ...                    ...           ...             ...                 ...
# 14878323  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 14878324  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 14878325  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 14878326  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 14878327  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
#
#                      outtime  death_time_from_intime  icu_mortality
# 0        2174-10-01 03:26:10                     NaT              0
# 1        2174-10-01 03:26:10                     NaT              0
# 2        2174-10-01 03:26:10                     NaT              0
# 3        2174-10-01 03:26:10                     NaT              0
# 4        2174-10-01 03:26:10                     NaT              0
# ...                      ...                     ...            ...
# 14878323 2167-04-30 10:11:50                     NaT              0
# 14878324 2167-04-30 10:11:50                     NaT              0
# 14878325 2167-04-30 10:11:50                     NaT              0
# 14878326 2167-04-30 10:11:50                     NaT              0
# 14878327 2167-04-30 10:11:50                     NaT              0
#
# [14878328 rows x 59 columns]

# %%
ltm_wide.stay_id.isna().sum()
# Out:
# 0

# %%
ltm_wide.loc[ltm_wide.stay_id=="mimic4-30002548"].sort_values("time").head(5)
# Out:
#               stay_id            time   FiO2  O2_arterial_saturation  \
# 1418  mimic4-30002548 0 days 00:53:17    NaN                     NaN
# 1419  mimic4-30002548 0 days 02:47:17    NaN                     NaN
# 1420  mimic4-30002548 0 days 03:06:17    NaN                     NaN
# 1421  mimic4-30002548 0 days 03:46:17  100.0                     NaN
# 1422  mimic4-30002548 0 days 03:49:17    NaN                     NaN
#
#       O2_pulseoxymetry_saturation  PEEP   PTT  alanine_aminotransferase  \
# 1418                          NaN   NaN   NaN                       NaN
# 1419                          NaN   NaN   NaN                       NaN
# 1420                          NaN   NaN   NaN                       NaN
# 1421                          NaN   5.0   NaN                       NaN
# 1422                          NaN   NaN  27.9                       NaN
#
#       albumin  alkaline_phosphatase  ...  sex  raw_height  raw_weight  \
# 1418      NaN                   NaN  ...  1.0       177.9      88.303
# 1419      NaN                   NaN  ...  1.0       177.9      88.303
# 1420      NaN                   NaN  ...  1.0       177.9      88.303
# 1421      NaN                   NaN  ...  1.0       177.9      88.303
# 1422      NaN                   NaN  ...  1.0       177.9      88.303
#
#       unit_type          origin             los              intime  \
# 1418    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
# 1419    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
# 1420    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
# 1421    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
# 1422    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
#
#                  outtime  death_time_from_intime  icu_mortality
# 1418 2111-08-18 18:50:31                     NaT              0
# 1419 2111-08-18 18:50:31                     NaT              0
# 1420 2111-08-18 18:50:31                     NaT              0
# 1421 2111-08-18 18:50:31                     NaT              0
# 1422 2111-08-18 18:50:31                     NaT              0
#
# [5 rows x 59 columns]

# %%
ltm_wide.columns
# Out:
# Index(['stay_id', 'time', 'FiO2', 'O2_arterial_saturation',
#        'O2_pulseoxymetry_saturation', 'PEEP', 'PTT',
#        'alanine_aminotransferase', 'albumin', 'alkaline_phosphatase',
#        'aspartate_aminotransferase', 'bicarbonate', 'bilirubine',
#        'blood_glucose', 'blood_urea_nitrogen', 'calcium', 'chloride',
#        'creatinine', 'expiratory_tidal_volume', 'glasgow_coma_score_eye',
#        'glasgow_coma_score_motor', 'glasgow_coma_score_verbal', 'heart_rate',
#        'hemoglobin', 'invasive_diastolic_blood_pressure',
#        'invasive_mean_blood_pressure', 'invasive_systolic_blood_pressure',
#        'lactate', 'magnesium', 'noninvasive_diastolic_blood_pressure',
#        'noninvasive_mean_blood_pressure',
#        'noninvasive_systolic_blood_pressure', 'pH', 'paCO2', 'paO2',
#        'phosphate', 'plateau_pressure', 'platelets', 'potassium',
#        'respiratory_rate', 'respiratory_rate_setting', 'sodium', 'temperature',
#        'tidal_volume_setting', 'urine_output', 'ventilator_mode',
#        'white_blood_cells', 'subject_id', 'raw_age', 'sex', 'raw_height',
#        'raw_weight', 'unit_type', 'origin', 'los', 'intime', 'outtime',
#        'death_time_from_intime', 'icu_mortality'],
#       dtype='object')

# %% [markdown]
# # Replace sentinel values with NaN

# %% [markdown]
# # Combine GCS
# # Choose ABP
# # O2 saturation

# %%
# Combine GCS
ltm_wide["glasgow_coma_score"] = (
    ltm_wide["glasgow_coma_score_eye"]
    + ltm_wide["glasgow_coma_score_motor"]
    + ltm_wide["glasgow_coma_score_verbal"]
)

# Replace invalid sums with NaN if any component is missing
ltm_wide["glasgow_coma_score"] = (
    ltm_wide["glasgow_coma_score"]
    .where(
        ltm_wide[[
            "glasgow_coma_score_eye",
            "glasgow_coma_score_motor",
            "glasgow_coma_score_verbal"
        ]].notna().all(axis=1)
    )
)

#ltm_wide['glasgow_coma_score'] = ltm_wide['glasgow_coma_score'].fillna(15)

# %%
# Combine ABP
df = ltm_wide.copy()
# ---------------------------
# 1. Compute invasive MAP if SBP/DBP are present
# ---------------------------
df["MAP_art_calc"] = (
    df["invasive_systolic_blood_pressure"] +
    2 * df["invasive_diastolic_blood_pressure"]
) / 3

# Pick invasive_mean if exists, else computed invasive
df["MAP_invasive"] = df["invasive_mean_blood_pressure"].combine_first(df["MAP_art_calc"])


# ---------------------------
# 2. Compute non-invasive MAP if SBP/DBP are present
# ---------------------------
df["MAP_nibp_calc"] = (
    df["noninvasive_systolic_blood_pressure"] +
    2 * df["noninvasive_diastolic_blood_pressure"]
) / 3

# Pick noninvasive_mean if exists, else computed non-invasive
df["MAP_noninvasive"] = df["noninvasive_mean_blood_pressure"].combine_first(df["MAP_nibp_calc"])


# ---------------------------
# 3. Final clinically informed hierarchy
# ---------------------------
# Use invasive MAP when available, else non-invasive MAP
df["arterial_blood_pressure"] = df["MAP_invasive"].combine_first(df["MAP_noninvasive"])


# Optional: cleanup intermediate columns if you want
df.drop(columns=[
    "MAP_art_calc",
    "MAP_invasive",
    "MAP_nibp_calc",
    "MAP_noninvasive"
], inplace=True)

ltm_wide["arterial_blood_pressure"] = df["arterial_blood_pressure"].copy()

# %%
# O2 saturation
# Clinically correct hierarchy: SaO₂ (ABG) > SpO₂ (pulse ox)
ltm_wide["oxygen_saturation"] = ltm_wide["O2_arterial_saturation"] \
    .combine_first(ltm_wide["O2_pulseoxymetry_saturation"])

# %%
mean_vars = ['temperature',
             'heart_rate',
             'arterial_blood_pressure',
             'urine_output',
             'paCO2',
             'respiratory_rate',
             'oxygen_saturation',
             'paO2']
               
last_vars = ['bicarbonate',
               'PTT',
               'hemoglobin',
               'creatinine',
               'blood_urea_nitrogen',
               'lactate',
               'glasgow_coma_score',
               'FiO2',
               'ventilator_mode'
               ]
baseline = ["stay_id", "subject_id", "raw_age", "sex", "raw_height", "raw_weight", "unit_type", "origin", "los", "intime", "outtime", "death_time_from_intime", "icu_mortality"]

# %%
confounders = mean_vars + last_vars

# %%
all_vars = confounders + baseline + ["time"]
ltm_wide_confounders = ltm_wide[all_vars]

# %%
all_vars
# Out:
# ['temperature',
#  'heart_rate',
#  'arterial_blood_pressure',
#  'urine_output',
#  'paCO2',
#  'respiratory_rate',
#  'oxygen_saturation',
#  'paO2',
#  'bicarbonate',
#  'PTT',
#  'hemoglobin',
#  'creatinine',
#  'blood_urea_nitrogen',
#  'lactate',
#  'glasgow_coma_score',
#  'FiO2',
#  'ventilator_mode',
#  'stay_id',
#  'raw_age',
#  'sex',
#  'raw_height',
#  'raw_weight',
#  'unit_type',
#  'origin',
#  'los',
#  'intime',
#  'outtime',
#  'death_time_from_intime',
#  'icu_mortality',
#  'time']

# %%
ltm_wide_confounders.stay_id.isna().sum()
# Out:
# 0

# %% [markdown]
# # Check t_adm, i.e., admission time/reference time. Ideally it should be 0 days 00:00:00. Correct?

# %%
ltm_wide_confounders_first_rows = (
    ltm_wide_confounders.sort_values(["stay_id", "time"])
       .groupby("stay_id", as_index=False)
       .first()
)

# %%
ltm_wide_confounders_first_rows
# Out:
#                stay_id  temperature  heart_rate  arterial_blood_pressure  \
# 0      mimic4-30000153    37.277779       104.0                     84.0
# 1      mimic4-30000213    36.333336        74.0                     95.0
# 2      mimic4-30000484    35.555557       106.0                     81.0
# 3      mimic4-30000646    37.111115       100.0                     75.0
# 4      mimic4-30000831    37.000000       131.0                    109.0
# ...                ...          ...         ...                      ...
# 94428  mimic4-39999384    36.777779        77.0                    113.0
# 94429  mimic4-39999552    36.777779        66.0                     84.0
# 94430  mimic4-39999562    36.888893        93.0                     87.0
# 94431  mimic4-39999810    36.722221        71.0                     98.0
# 94432  mimic4-39999858    37.111115        79.0                     82.0
#
#        urine_output  paCO2  respiratory_rate  oxygen_saturation   paO2  \
# 0             280.0   45.0              16.0              100.0  221.0
# 1             550.0   45.0              22.0               96.0   63.0
# 2             260.0   59.0              22.0              100.0   21.0
# 3               NaN   30.0              28.0               97.0   71.0
# 4             250.0   38.0              30.0               95.0   77.0
# ...             ...    ...               ...                ...    ...
# 94428         120.0    NaN              17.0              100.0    NaN
# 94429         350.0   30.0              14.0              100.0  343.0
# 94430         900.0    NaN              15.0               94.0    NaN
# 94431           NaN    NaN              20.0               93.0    NaN
# 94432           NaN    NaN              24.0               97.0    NaN
#
#        bicarbonate  ...  raw_height  raw_weight         unit_type  \
# 0             19.0  ...         NaN     73.0000            Trauma
# 1             22.0  ...      160.01     84.7000           Medical
# 2             27.0  ...      162.78     68.4178           Medical
# 3             25.0  ...      170.09     76.3174           Cardiac
# 4             25.0  ...      182.94         NaN           Cardiac
# ...            ...  ...         ...         ...               ...
# 94428         24.0  ...         NaN     66.9196          Surgical
# 94429         27.0  ...      172.86     64.4613           Cardiac
# 94430         26.0  ...         NaN     62.0000      Neurological
# 94431         24.0  ...         NaN     72.0000      Neurological
# 94432         23.0  ...         NaN    123.8000  Medical-Surgical
#
#              origin                    los              intime  \
# 0         Emergency        1 days 15:17:10 2174-09-29 12:09:00
# 1             Other        1 days 15:14:48 2162-06-21 05:38:00
# 2         Emergency 2 days 11:29:35.999999 2136-01-14 17:23:32
# 3         Emergency        4 days 16:44:26 2194-04-29 01:39:22
# 4             Other        2 days 16:55:24 2140-04-17 21:26:33
# ...             ...                    ...                 ...
# 94428         Other        1 days 06:37:06 2158-05-24 19:50:01
# 94429         Other 1 days 04:01:21.999999 2186-07-17 14:27:43
# 94430         Other        4 days 23:54:40 2129-01-24 17:24:09
# 94431         Other        4 days 17:50:57 2115-12-01 00:37:00
# 94432  Direct Admit        3 days 21:35:50 2167-04-26 12:36:00
#
#                   outtime  death_time_from_intime  icu_mortality  \
# 0     2174-10-01 03:26:10                     NaT              0
# 1     2162-06-22 20:52:48      1363 days 18:22:00              0
# 2     2136-01-17 04:53:08        37 days 06:36:28              0
# 3     2194-05-03 18:23:48         6 days 22:20:38              1
# 4     2140-04-20 14:21:57                     NaT              0
# ...                   ...                     ...            ...
# 94428 2158-05-26 02:27:07                     NaT              0
# 94429 2186-07-18 18:29:05                     NaT              0
# 94430 2129-01-29 17:18:49                     NaT              0
# 94431 2115-12-05 18:27:57                     NaT              0
# 94432 2167-04-30 10:11:50                     NaT              0
#
#                  time
# 0     0 days 00:03:00
# 1     0 days 00:07:00
# 2     0 days 01:14:28
# 3     0 days 00:01:38
# 4     0 days 00:04:27
# ...               ...
# 94428 0 days 01:09:59
# 94429 0 days 00:03:17
# 94430 0 days 00:18:51
# 94431 0 days 00:18:00
# 94432 0 days 00:24:00
#
# [94433 rows x 30 columns]

# %%
# Check distribution of first time point
ltm_wide_confounders_first_rows["time_hours"] = (
    ltm_wide_confounders_first_rows["time"].dt.total_seconds() / 3600
)
ltm_wide_confounders_first_rows["time_hours"].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Conclusion. Most data are recorded within 0 to 2 hours of admission. So, the first data point belongs to the bucket [0h, 12h]. i.e. data at 12th hour point.

# %% [markdown]
# ## Remove stay_ids which do not have data for more than >=12h

# %%
# 12 hours in pandas Timedelta
MIN_HOURS = pd.Timedelta(hours=12)

# Compute maximum elapsed time per stay_id
max_time_per_stay = ltm_wide_confounders.groupby("stay_id")["time"].max()

# Identify which stay_ids have < 12h of follow-up
short_stays = max_time_per_stay[max_time_per_stay < MIN_HOURS].index

# Number of stay_ids dropped
n_dropped = len(short_stays)
print("Number of stay_ids dropped:", n_dropped)
# Out:
# Number of stay_ids dropped: 5091

# %%
short_stays
# Out:
# Index(['mimic4-30005363', 'mimic4-30010076', 'mimic4-30011777',
#        'mimic4-30012150', 'mimic4-30016590', 'mimic4-30017259',
#        'mimic4-30017404', 'mimic4-30017418', 'mimic4-30017436',
#        'mimic4-30019872',
#        ...
#        'mimic4-39979841', 'mimic4-39981242', 'mimic4-39982932',
#        'mimic4-39983771', 'mimic4-39984717', 'mimic4-39986298',
#        'mimic4-39989651', 'mimic4-39989920', 'mimic4-39992901',
#        'mimic4-39996783'],
#       dtype='object', name='stay_id', length=5091)

# %%
ltm_wide_confounders.loc[ltm_wide_confounders.stay_id=="mimic4-30019872"]
# Out:
#        temperature  heart_rate  arterial_blood_pressure  urine_output  paCO2  \
# 28901    36.055557         NaN                      NaN           NaN    NaN
# 28902          NaN        87.0                      NaN           NaN    NaN
# 28903          NaN         NaN                      NaN           NaN    NaN
# 28904          NaN        69.0                      NaN           NaN    NaN
# 28905          NaN        73.0                      NaN           NaN    NaN
# 28906          NaN        66.0                      NaN           NaN    NaN
# 28907          NaN         NaN                      NaN           NaN    NaN
# 28908          NaN         NaN                      NaN           NaN   52.0
# 28909          NaN         NaN                      NaN         400.0    NaN
# 28910          NaN         NaN                      NaN           NaN    NaN
# 28911          NaN        73.0                      NaN           NaN    NaN
# 28912          NaN        65.0                      NaN           NaN    NaN
# 28913    37.000000        70.0                      NaN         140.0    NaN
# 28914          NaN        66.0                      NaN           NaN    NaN
# 28915    37.166668        66.0                      NaN          60.0    NaN
# 28916          NaN        70.0                      NaN           NaN    NaN
# 28917          NaN         NaN                      NaN           NaN    NaN
# 28918          NaN         NaN                      NaN           NaN    NaN
# 28919          NaN        66.0                      NaN         100.0    NaN
# 28920    37.555557        71.0                      NaN           NaN    NaN
#
#        respiratory_rate  oxygen_saturation  paO2  bicarbonate        PTT  ...  \
# 28901               NaN                NaN   NaN          NaN        NaN  ...
# 28902               NaN                NaN   NaN          NaN        NaN  ...
# 28903               NaN               98.0   NaN         31.0  38.299999  ...
# 28904               NaN              100.0   NaN          NaN        NaN  ...
# 28905               NaN               99.0   NaN          NaN        NaN  ...
# 28906               NaN                NaN   NaN          NaN        NaN  ...
# 28907               NaN               98.0   NaN          NaN        NaN  ...
# 28908               NaN               94.0  82.0          NaN        NaN  ...
# 28909               NaN                NaN   NaN          NaN        NaN  ...
# 28910               NaN                NaN   NaN          NaN        NaN  ...
# 28911               NaN              100.0   NaN          NaN        NaN  ...
# 28912               NaN              100.0   NaN          NaN        NaN  ...
# 28913              20.0               99.0   NaN          NaN        NaN  ...
# 28914               NaN               98.0   NaN          NaN        NaN  ...
# 28915               NaN               99.0   NaN          NaN        NaN  ...
# 28916               NaN               94.0   NaN          NaN        NaN  ...
# 28917              18.0                NaN   NaN          NaN        NaN  ...
# 28918               NaN                NaN   NaN          NaN        NaN  ...
# 28919              18.0               96.0   NaN          NaN        NaN  ...
# 28920              16.0               94.0   NaN          NaN        NaN  ...
#
#        raw_height  raw_weight  unit_type  origin             los  \
# 28901      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28902      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28903      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28904      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28905      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28906      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28907      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28908      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28909      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28910      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28911      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28912      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28913      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28914      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28915      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28916      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28917      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28918      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28919      175.13      44.492    Cardiac   Other 0 days 05:43:55
# 28920      175.13      44.492    Cardiac   Other 0 days 05:43:55
#
#                    intime             outtime death_time_from_intime  \
# 28901 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28902 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28903 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28904 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28905 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28906 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28907 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28908 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28909 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28910 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28911 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28912 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28913 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28914 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28915 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28916 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28917 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28918 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28919 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
# 28920 2174-09-20 12:44:35 2174-09-20 18:28:30                    NaT
#
#        icu_mortality            time
# 28901              0 0 days 01:15:25
# 28902              0 0 days 01:16:25
# 28903              0 0 days 01:24:25
# 28904              0 0 days 01:25:25
# 28905              0 0 days 01:30:25
# 28906              0 0 days 01:35:25
# 28907              0 0 days 01:36:25
# 28908              0 0 days 01:37:25
# 28909              0 0 days 01:43:25
# 28910              0 0 days 01:44:25
# 28911              0 0 days 01:45:25
# 28912              0 0 days 02:00:25
# 28913              0 0 days 02:15:25
# 28914              0 0 days 02:45:25
# 28915              0 0 days 03:15:25
# 28916              0 0 days 03:45:25
# 28917              0 0 days 04:03:25
# 28918              0 0 days 04:06:25
# 28919              0 0 days 04:15:25
# 28920              0 0 days 05:15:25
#
# [20 rows x 30 columns]

# %%
# Filter mimicdata to keep only stay_ids with >= 12h of follow-up
ltm_wide_confounders = ltm_wide_confounders[~ltm_wide_confounders["stay_id"].isin(short_stays)]

print("Number remaining:", ltm_wide_confounders['stay_id'].nunique())
# Out:
# Number remaining: 89342

# %% [markdown]
# # Debugging vent_mode and vent_mode_hours

# %%
ltm_wide_confounders.ventilator_mode.value_counts(dropna=False)
# Out:
# ventilator_mode
# NaN     14315700
# 14.0      202660
# 10.0      181924
# 9.0        18948
# 22.0       13322
# 41.0       11871
# 31.0       11333
# 29.0        5327
# 27.0        4315
# 17.0        3560
# 36.0        2021
# 21.0        1975
# 12.0        1371
# 2.0         1075
# 11.0        1052
# 8.0          998
# 13.0         985
# 16.0         803
# 42.0         649
# 5.0          625
# 38.0         610
# 25.0         467
# 26.0         415
# 35.0         408
# 28.0         328
# 19.0         210
# 7.0          133
# 4.0          106
# 20.0          68
# 32.0          40
# 34.0          39
# 6.0           38
# 3.0           34
# 30.0          27
# 23.0          19
# 33.0          16
# 39.0          16
# 15.0          14
# 18.0           8
# 37.0           7
# 40.0           5
# 1.0            3
# 24.0           2
# Name: count, dtype: int64

# %% [markdown]
# ## vent_mode map back to categorical

# %%
# Load vent_mode_map.json
with open("vent_mode_map.json", "r") as g:
    ventmode_map = json.load(g)
reverse_ventmode_map = {v: k for k, v in ventmode_map.items()}
ltm_wide_confounders["ventilator_mode"] = ltm_wide_confounders["ventilator_mode"].fillna(99)
ltm_wide_confounders["ventilator_mode"] = ltm_wide_confounders["ventilator_mode"].map(reverse_ventmode_map)

# %%
ltm_wide_confounders.ventilator_mode.value_counts(dropna=False)
# Out:
# ventilator_mode
# unknown                   14315700
# CPAP/PSV                    202660
# CMV/ASSIST/AutoFlow         181924
# CMV/ASSIST                   18948
# MMV/PSV/AutoFlow             13322
# Standby                      11871
# PSV/SBT                      11333
# PRVC/AC                       5327
# PCV+Assist                    4315
# CPAP/PSV+ApnVol               3560
# SIMV/PSV/AutoFlow             2021
# MMV/PSV                       1975
# CPAP                          1371
# APRV                          1075
# CMV/AutoFlow                  1052
# CMV                            998
# CPAP/PPS                       985
# CPAP/PSV+ApnPres               803
# VOL/AC                         649
# APV (cmv)                      625
# SPONT                          610
# PCV+                           467
# PCV+/PSV                       415
# SIMV/PSV                       408
# PRES/AC                        328
# MMV                            210
# Apnea Ventilation              133
# APRV/Biphasic+ApnVol           106
# MMV/AutoFlow                    68
# SIMV                            40
# SIMV/PRES                       39
# Ambient                         38
# APRV/Biphasic+ApnPress          34
# PRVC/SIMV                       27
# P-CMV                           19
# SIMV/AutoFlow                   16
# SYNCHRON MASTER                 16
# CPAP/PSV+Apn TCPL               14
# DuoPaP                           8
# SIMV/VOL                         7
# SYNCHRON SLAVE                   5
# (S) CMV                          3
# P-SIMV                           2
# Name: count, dtype: int64

# %%
# For one of the patients
ltm_wide_confounders.stay_id.unique()
# Out:
# array(['mimic4-30000153', 'mimic4-30000213', 'mimic4-30000484', ...,
#        'mimic4-39999562', 'mimic4-39999810', 'mimic4-39999858'],
#       dtype=object)

# %%
ltm_wide_confounders.loc[ltm_wide_confounders.ventilator_mode!="unknown"].stay_id.unique()
# Out:
# array(['mimic4-30000153', 'mimic4-30001148', 'mimic4-30001656', ...,
#        'mimic4-39997753', 'mimic4-39998012', 'mimic4-39999552'],
#       dtype=object)

# %%
ltm_wide_confounders.loc[ltm_wide_confounders.stay_id=="mimic4-39999552"][["time", "ventilator_mode"]]
# Out:
#                     time      ventilator_mode
# 14877731 0 days 00:03:17              unknown
# 14877732 0 days 00:57:17              unknown
# 14877733 0 days 00:59:17              unknown
# 14877734 0 days 01:32:17           CMV/ASSIST
# 14877735 0 days 02:16:17              unknown
# 14877736 0 days 02:24:17              unknown
# 14877737 0 days 02:25:17  CMV/ASSIST/AutoFlow
# 14877738 0 days 02:31:17              unknown
# 14877739 0 days 02:32:17              unknown
# 14877740 0 days 02:41:17              unknown
# 14877741 0 days 02:44:17              unknown
# 14877742 0 days 02:46:17              unknown
# 14877743 0 days 03:02:17              unknown
# 14877744 0 days 03:32:17              unknown
# 14877745 0 days 04:02:17              unknown
# 14877746 0 days 04:32:17              unknown
# 14877747 0 days 04:34:17              unknown
# 14877748 0 days 05:32:17  CMV/ASSIST/AutoFlow
# 14877749 0 days 05:39:17              unknown
# 14877750 0 days 06:00:17              unknown
# 14877751 0 days 06:27:17              unknown
# 14877752 0 days 06:32:17     CPAP/PSV+ApnPres
# 14877753 0 days 07:32:17              unknown
# 14877754 0 days 07:57:17              unknown
# 14877755 0 days 08:32:17              unknown
# 14877756 0 days 09:32:17              unknown
# 14877757 0 days 10:07:17              unknown
# 14877758 0 days 10:32:17              unknown
# 14877759 0 days 10:47:17              unknown
# 14877760 0 days 10:52:17              unknown
# 14877761 0 days 10:57:17              unknown
# 14877762 0 days 11:02:17              unknown
# 14877763 0 days 11:32:17              unknown
# 14877764 0 days 12:17:17              unknown
# 14877765 0 days 12:32:17              unknown
# 14877766 0 days 13:32:17              unknown
# 14877767 0 days 14:32:17              unknown
# 14877768 0 days 14:38:17              unknown
# 14877769 0 days 14:52:17              unknown
# 14877770 0 days 15:32:17              unknown
# 14877771 0 days 16:32:17              unknown
# 14877772 0 days 17:32:17              unknown
# 14877773 0 days 17:41:17              unknown
# 14877774 0 days 18:32:17              unknown
# 14877775 0 days 19:32:17              unknown
# 14877776 0 days 19:46:17              unknown
# 14877777 0 days 20:32:17              unknown
# 14877778 0 days 20:53:17              unknown
# 14877779 0 days 21:02:17              unknown
# 14877780 0 days 21:32:17              unknown
# 14877781 0 days 22:32:17              unknown
# 14877782 0 days 22:38:17              unknown
# 14877783 0 days 23:32:17              unknown
# 14877784 0 days 23:33:17              unknown
# 14877785 1 days 00:32:17              unknown
# 14877786 1 days 01:32:17              unknown
# 14877787 1 days 01:41:17              unknown
# 14877788 1 days 02:32:17              unknown

# %%
#ltm_wide_confounders.loc[ltm_wide_confounders.stay_id=="mimic4-39996123"][["time", "ventilator_mode"]].to_csv("bg_mimic4-39996123.csv")

# %% [markdown]
# # Gridding data for every 12h

# %%
df = ltm_wide_confounders.copy()

# Ensure correct dtype
df["time"] = pd.to_timedelta(df["time"])
df["los"]  = pd.to_timedelta(df["los"])

# --------------------------------------------------------------------
# Function to grid one stay_id
# --------------------------------------------------------------------
def process_stay(stay_df):
    stay_df = stay_df.sort_values("time")
    los = stay_df["los"].iloc[0]

    # LOS in hours
    total_hours = los.total_seconds() / 3600

    # Grid end points: 12h, 24h, 36h, ... up to ≥ LOS
    grid_ends_hours = np.arange(12, total_hours + 12, 12)
    grid_ends = pd.to_timedelta(grid_ends_hours, unit="h")

    rows = []

    for end in grid_ends:
        start = end - pd.Timedelta(hours=12)

        # Window: (start, end] except first includes [0, end]
        if start <= pd.Timedelta(0):
            window = stay_df[(stay_df["time"] >= pd.Timedelta(0)) &
                             (stay_df["time"] <= end)]
        else:
            window = stay_df[(stay_df["time"] > start) &
                             (stay_df["time"] <= end)]

        row = {
            "stay_id": stay_df["stay_id"].iloc[0],
            "grid_end": end,
        }

        # ----------------------------------------------------------
        # Compute vent_mode__hours_since_last__last_12h
        # Meaning: hours since vent mode was last RECORDED (ignore unknown)
        # ----------------------------------------------------------
        if len(window) > 0:
            # Extract only rows where vent mode is known
            v_known = window[
                window["ventilator_mode"].notna() &
                (window["ventilator_mode"] != "unknown")
            ][["time", "ventilator_mode"]]

            if len(v_known) > 0:
                # Take the LAST time vent mode was recorded
                last_recorded_time = v_known["time"].iloc[-1]

                # Compute hours since that time up to the end of the window
                hours_since = (end - last_recorded_time).total_seconds() / 3600.0

                # Clip to [0, 12]
                hours_since = min(max(hours_since, 0), 12)
            else:
                # No known vent mode recorded within window
                hours_since = np.nan
        else:
            hours_since = np.nan

        row["vent_mode__hours_since_last__last_12h"] = hours_since
        # ----------------------------------------------------------
        
        # Mean variables
        for vname in mean_vars:
            row[vname] = window[vname].mean() if len(window) else np.nan

        # Last variables
        #for vname in last_vars:
        #    row[vname] = window[vname].iloc[-1] if len(window) else np.nan



        # Last variables — ignore "unknown"
        for vname in last_vars:
            if len(window) == 0:
                row[vname] = np.nan
            else:
                # Drop unknowns
                w = window[window[vname] != "unknown"]

                if len(w) > 0:
                    # Last known (non-unknown) value
                    row[vname] = w[vname].iloc[-1]
                else:
                    # All unknown → return NaN
                    row[vname] = np.nan



        # Baseline variables
        for b in baseline:
            row[b] = stay_df[b].iloc[0]

        rows.append(row)

    return pd.DataFrame(rows)



# --------------------------------------------------------------------
# Apply to all stay_ids
# --------------------------------------------------------------------
ltm_grided = (
    df.groupby("stay_id", group_keys=False)
      .apply(process_stay)
      .reset_index(drop=True)
)
# Out:
# /tmp/ipykernel_493704/1684453530.py:110: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(process_stay)

# %%
ltm_grided.loc[ltm_grided.stay_id=="mimic4-39987417"][["grid_end", "ventilator_mode", "vent_mode__hours_since_last__last_12h"]]
# Out:
#               grid_end      ventilator_mode  \
# 726135 0 days 12:00:00  CMV/ASSIST/AutoFlow
# 726136 1 days 00:00:00  CMV/ASSIST/AutoFlow
# 726137 1 days 12:00:00  CMV/ASSIST/AutoFlow
# 726138 2 days 00:00:00  CMV/ASSIST/AutoFlow
#
#         vent_mode__hours_since_last__last_12h
# 726135                               2.041944
# 726136                               1.041944
# 726137                               1.041944
# 726138                               9.041944

# %%
ltm_grided.loc[ltm_grided.stay_id=="mimic4-39996123"][["grid_end", "ventilator_mode", "vent_mode__hours_since_last__last_12h"]]
# Out:
#               grid_end      ventilator_mode  \
# 726576 0 days 12:00:00  CMV/ASSIST/AutoFlow
# 726577 1 days 00:00:00              Standby
# 726578 1 days 12:00:00                  NaN
# 726579 2 days 00:00:00                  NaN
# 726580 2 days 12:00:00                  NaN
# 726581 3 days 00:00:00                  NaN
# 726582 3 days 12:00:00                  NaN
# 726583 4 days 00:00:00                  NaN
#
#         vent_mode__hours_since_last__last_12h
# 726576                               1.783333
# 726577                               5.366667
# 726578                                    NaN
# 726579                                    NaN
# 726580                                    NaN
# 726581                                    NaN
# 726582                                    NaN
# 726583                                    NaN

# %%
ltm_grided.stay_id.isna().sum()
# Out:
# 0

# %%
ltm_grided
# Out:
#                 stay_id        grid_end  \
# 0       mimic4-30000153 0 days 12:00:00
# 1       mimic4-30000153 1 days 00:00:00
# 2       mimic4-30000153 1 days 12:00:00
# 3       mimic4-30000153 2 days 00:00:00
# 4       mimic4-30000213 0 days 12:00:00
# ...                 ...             ...
# 726804  mimic4-39999858 2 days 00:00:00
# 726805  mimic4-39999858 2 days 12:00:00
# 726806  mimic4-39999858 3 days 00:00:00
# 726807  mimic4-39999858 3 days 12:00:00
# 726808  mimic4-39999858 4 days 00:00:00
#
#         vent_mode__hours_since_last__last_12h  temperature  heart_rate  \
# 0                                    6.983333    37.625000  109.076920
# 1                                         NaN    37.333332  104.416664
# 2                                         NaN    37.569443  102.250000
# 3                                         NaN          NaN   99.666664
# 4                                         NaN    36.911114   78.384613
# ...                                       ...          ...         ...
# 726804                                    NaN    36.944447   64.833336
# 726805                                    NaN    36.902779   64.250000
# 726806                                    NaN    36.870373   68.166664
# 726807                                    NaN    36.722225   64.666664
# 726808                                    NaN    37.222225   70.125000
#
#         arterial_blood_pressure  urine_output  paCO2  respiratory_rate  \
# 0                     84.380959     82.222221   44.0         17.230770
# 1                     91.846153     55.000000    NaN         12.500000
# 2                     95.476189     83.125000    NaN         14.272727
# 3                     91.333336     70.000000    NaN         15.333333
# 4                     78.846153    324.166656   41.5         21.692308
# ...                         ...           ...    ...               ...
# 726804                77.250000           NaN    NaN         21.500000
# 726805                81.818184           NaN    NaN         23.916666
# 726806                71.166664           NaN    NaN         24.500000
# 726807                69.666664           NaN    NaN         25.666666
# 726808                74.000000           NaN    NaN         26.750000
#
#         oxygen_saturation  ...  sex  raw_height  raw_weight         unit_type  \
# 0               97.923080  ...  1.0         NaN        73.0            Trauma
# 1               95.250000  ...  1.0         NaN        73.0            Trauma
# 2               98.545456  ...  1.0         NaN        73.0            Trauma
# 3              100.000000  ...  1.0         NaN        73.0            Trauma
# 4               98.846153  ...  1.0      160.01        84.7           Medical
# ...                   ...  ...  ...         ...         ...               ...
# 726804          95.166664  ...  1.0         NaN       123.8  Medical-Surgical
# 726805          92.550003  ...  1.0         NaN       123.8  Medical-Surgical
# 726806          93.250000  ...  1.0         NaN       123.8  Medical-Surgical
# 726807          92.166664  ...  1.0         NaN       123.8  Medical-Surgical
# 726808          92.875000  ...  1.0         NaN       123.8  Medical-Surgical
#
#               origin             los              intime             outtime  \
# 0          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 1          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 2          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 3          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 4              Other 1 days 15:14:48 2162-06-21 05:38:00 2162-06-22 20:52:48
# ...              ...             ...                 ...                 ...
# 726804  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726805  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726806  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726807  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726808  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
#
#         death_time_from_intime icu_mortality
# 0                          NaT             0
# 1                          NaT             0
# 2                          NaT             0
# 3                          NaT             0
# 4           1363 days 18:22:00             0
# ...                        ...           ...
# 726804                     NaT             0
# 726805                     NaT             0
# 726806                     NaT             0
# 726807                     NaT             0
# 726808                     NaT             0
#
# [726809 rows x 31 columns]

# %%
ltm_grided.columns
# Out:
# Index(['stay_id', 'grid_end', 'vent_mode__hours_since_last__last_12h',
#        'temperature', 'heart_rate', 'arterial_blood_pressure', 'urine_output',
#        'paCO2', 'respiratory_rate', 'oxygen_saturation', 'paO2', 'bicarbonate',
#        'PTT', 'hemoglobin', 'creatinine', 'blood_urea_nitrogen', 'lactate',
#        'glasgow_coma_score', 'FiO2', 'ventilator_mode', 'raw_age', 'sex',
#        'raw_height', 'raw_weight', 'unit_type', 'origin', 'los', 'intime',
#        'outtime', 'death_time_from_intime', 'icu_mortality'],
#       dtype='object')

# %%
ltm_grided.vent_mode__hours_since_last__last_12h.describe()
# Out:
# count    149128.000000
# mean          2.925333
# std           2.630336
# min           0.000000
# 25%           1.090556
# 50%           2.240139
# 75%           3.678403
# max          11.999444
# Name: vent_mode__hours_since_last__last_12h, dtype: float64

# %%
ltm_grided.vent_mode__hours_since_last__last_12h.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
var = "vent_mode__hours_since_last__last_12h"
sns.kdeplot(data=ltm_grided, x=var, fill=True, bw_adjust=1)
plt.title(var)
plt.tight_layout()
plt.show()

# %%
ltm_grided.loc[ltm_grided.stay_id=="mimic4-30002548"]
# Out:
#             stay_id        grid_end  vent_mode__hours_since_last__last_12h  \
# 74  mimic4-30002548 0 days 12:00:00                                    NaN
# 75  mimic4-30002548 1 days 00:00:00                                    NaN
# 76  mimic4-30002548 1 days 12:00:00                                    NaN
#
#     temperature  heart_rate  arterial_blood_pressure  urine_output      paCO2  \
# 74    36.622223   79.230766                71.000000        225.00  43.166668
# 75    36.944447   70.500000                79.571426         87.50        NaN
# 76    37.333332   76.500000                87.750000         38.75        NaN
#
#     respiratory_rate  oxygen_saturation  ...  sex  raw_height  raw_weight  \
# 74         13.384615          98.461540  ...  1.0       177.9      88.303
# 75         18.250000          98.666664  ...  1.0       177.9      88.303
# 76         21.000000          97.500000  ...  1.0       177.9      88.303
#
#     unit_type          origin             los              intime  \
# 74    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
# 75    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
# 76    Cardiac  Operating Room 1 days 05:36:48 2111-08-17 13:13:43
#
#                outtime  death_time_from_intime icu_mortality
# 74 2111-08-18 18:50:31                     NaT             0
# 75 2111-08-18 18:50:31                     NaT             0
# 76 2111-08-18 18:50:31                     NaT             0
#
# [3 rows x 31 columns]

# %%
ltm_grided.loc[ltm_grided.stay_id=="mimic4-30002548"].ventilator_mode
# Out:
# 74    NaN
# 75    NaN
# 76    NaN
# Name: ventilator_mode, dtype: object

# %%
ltm_grided.stay_id.nunique()
# Out:
# 89342

# %% [markdown]
# ## Renaming column name from those in raw data to the __mean__last_12 and __last__last_12h

# %%
# Load mappings.json
with open("mappings.json", "r") as f:
    mappings = json.load(f)

# Apply renaming
ltm_grided = ltm_grided.rename(columns=mappings)

# %%
ltm_grided.stay_id.nunique()
# Out:
# 89342

# %%
ltm_grided["vent_mode__last__last_12h"].value_counts(dropna=False)
# Out:
# vent_mode__last__last_12h
# NaN                       577681
# CPAP/PSV                   67413
# CMV/ASSIST/AutoFlow        49575
# Standby                     8527
# PSV/SBT                     5666
# CMV/ASSIST                  5156
# MMV/PSV/AutoFlow            3955
# PRVC/AC                     1637
# PCV+Assist                  1253
# CPAP/PSV+ApnVol             1072
# CPAP                         524
# MMV/PSV                      521
# APV (cmv)                    429
# SPONT                        395
# SIMV/PSV/AutoFlow            386
# CMV                          382
# CPAP/PPS                     331
# VOL/AC                       316
# APRV                         293
# CPAP/PSV+ApnPres             290
# CMV/AutoFlow                 279
# PCV+                         138
# SIMV/PSV                     114
# PCV+/PSV                     112
# PRES/AC                      101
# MMV                           61
# Apnea Ventilation             44
# Ambient                       34
# APRV/Biphasic+ApnVol          28
# SIMV                          15
# MMV/AutoFlow                  15
# SIMV/PRES                     11
# PRVC/SIMV                     10
# APRV/Biphasic+ApnPress        10
# P-CMV                          9
# CPAP/PSV+Apn TCPL              7
# DuoPaP                         6
# SIMV/AutoFlow                  4
# SYNCHRON MASTER                4
# P-SIMV                         2
# (S) CMV                        2
# SIMV/VOL                       1
# Name: count, dtype: int64

# %% [markdown]
# ## Mortality within X days after discharge

# %%
# Ensure correct dtypes
ltm_grided["intime"]  = pd.to_datetime(ltm_grided["intime"], errors="coerce")
ltm_grided["outtime"] = pd.to_datetime(ltm_grided["outtime"], errors="coerce")

# death_time_from_intime must be timedelta
ltm_grided["death_time_from_intime"] = pd.to_timedelta(
    ltm_grided["death_time_from_intime"], errors="coerce"
)

# Absolute death time = intime + death offset
ltm_grided["death_abs_time"] = ltm_grided["intime"] + ltm_grided["death_time_from_intime"]

# 7-day post-ICU mortality (row level)
ltm_grided["mortality_after_discharge"] = (
    ltm_grided["death_abs_time"].notna()
    & (ltm_grided["death_abs_time"] > ltm_grided["outtime"])
    & (ltm_grided["death_abs_time"] <= ltm_grided["outtime"] + pd.Timedelta(days=7))
).astype(int)

# %%
#ratio of mortality
last_rows = ltm_grided.groupby("stay_id").tail(1)
(last_rows["mortality_after_discharge"] == 1).mean()
# Out:
# 0.033041570593897604

# %% [markdown]
# ## Check if "Mortality" is in-icu mortality

# %%
#ratio of icu mortality
(last_rows["icu_mortality"] == 1).mean()
# Out:
# 0.11200779028900182

# %% [markdown]
# ## Map to standard categories (invasive_controlled, invasive assisted etc)

# %%
ltm_grided["vent_mode__last__last_12h"]
# Out:
# 0         CPAP/PSV
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 726804         NaN
# 726805         NaN
# 726806         NaN
# 726807         NaN
# 726808         NaN
# Name: vent_mode__last__last_12h, Length: 726809, dtype: object

# %%
# Mapping vent_mode__last__last_12h from raw categories → derived categories
vent_mode_map = {
    "SPONT": "invasive_assisted",
    "CMV/ASSIST/AutoFlow": "invasive_controlled",
    "PSV/SBT": "invasive_assisted",
    "CMV/ASSIST": "invasive_controlled",
    "invasive_assisted": "invasive_assisted",
    "APV (cmv)": "invasive_controlled",
    "invasive_controlled": "invasive_controlled",
    "CPAP/PSV+ApnVol": "invasive_assisted",
    "SIMV/PSV/AutoFlow": "invasive_controlled",
    "CMV/AutoFlow": "invasive_controlled",
    "Spontaneous (S)": "invasive_assisted",
    "PCV+Assist": "invasive_controlled",
    "(S) CMV": "invasive_controlled",
    "Not applicable": "cancelled",
    "MMV/PSV/AutoFlow": "invasive_assisted",
    "PCV+": "invasive_controlled",
    "MMV/PSV": "invasive_assisted",
    "niv_unknown": "niv_unknown",
    "CPAP/PSV+ApnPres": "invasive_assisted",
    "PRES/AC": "invasive_controlled",
    "APRV/Biphasic+ApnVol": "invasive_controlled",
    "SIMV/PSV": "invasive_controlled",
    "CMV": "invasive_controlled",
    "Spontaneous/Timed (S/T) (Back up)": "cancelled",
    "VOL/AC": "invasive_controlled",
    "PCV+/PSV": "invasive_controlled",
    "SIMV/PRES": "invasive_controlled",
    "Apnea Ventilation": "cancelled",
    "niv_assisted": "niv_assisted",
    "APV (simv)": "invasive_controlled",
    "SYNCHRON MASTER": "cancelled",
    "SIMV/VOL": "invasive_controlled",
    "PRVC/SIMV": "invasive_controlled",
    "APRV/Biphasic+ApnPress": "invasive_controlled",
    "MMV/AutoFlow": "invasive_assisted",
    "P-SIMV": "invasive_controlled",
    "Timed (T)": "cancelled",
    "CPAP/PSV+Apn TCPL": "invasive_assisted",
    "SYNCHRON SLAVE": "cancelled",
    "DuoPaP": "invasive_assisted",
    "nCPAP-PS": "niv_assisted",
    "Standby": "invasive_assisted"
}
ltm_grided["vent_mode__last__last_12h"] = ltm_grided["vent_mode__last__last_12h"].map(vent_mode_map)

# %%
ltm_grided["vent_mode__last__last_12h"] = ltm_grided["vent_mode__last__last_12h"].fillna("unknown")

# %%
ltm_grided["vent_mode__last__last_12h"].value_counts(dropna=False)
# Out:
# vent_mode__last__last_12h
# unknown                648002
# invasive_controlled     58305
# invasive_assisted       20454
# cancelled                  48
# Name: count, dtype: int64

# %% [markdown]
# ## Check mim, max and distributions (density plot)

# %%
L_confounders = list(mappings.values()) + ["vent_mode__hours_since_last__last_12h"]

# %%
L_confounders
# Out:
# ['bicarbonate_arterial__last__last_12h',
#  'activated_partial_thromboplastin_time__last__last_12h',
#  'temperature__mean__last_12h',
#  'hemoglobin__last__last_12h',
#  'heart_rate__mean__last_12h',
#  'arterial_blood_pressure_mean__mean__last_12h',
#  'creatinine__last__last_12h',
#  'ureum__last__last_12h',
#  'fluid_out_urine__mean__last_12h',
#  'lactate__last__last_12h',
#  'glasgow_coma_scale_total__last__last_12h',
#  'pco2_arterial__mean__last_12h',
#  'respiratory_rate_measured__mean__last_12h',
#  'o2_saturation__mean__last_12h',
#  'o2_flow__last__last_12h',
#  'po2_arterial__mean__last_12h',
#  'vent_mode__last__last_12h',
#  'vent_mode__hours_since_last__last_12h']

# %%
L_to_clip = [
 'bicarbonate_arterial__last__last_12h',
 'activated_partial_thromboplastin_time__last__last_12h',
 'temperature__mean__last_12h',
 'hemoglobin__last__last_12h',
 'heart_rate__mean__last_12h',
 'arterial_blood_pressure_mean__mean__last_12h',
 'creatinine__last__last_12h',
 'ureum__last__last_12h',
 'fluid_out_urine__mean__last_12h',
 'lactate__last__last_12h',
 #'glasgow_coma_scale_total__last__last_12h',
 'pco2_arterial__mean__last_12h',
 'respiratory_rate_measured__mean__last_12h',
 'o2_saturation__mean__last_12h',
 'o2_flow__last__last_12h',
 'po2_arterial__mean__last_12h',
 #'vent_mode__last__last_12h',
 #'vent_mode__hours_since_last__last_12h'
 ]

# %%
ltm_grided.hemoglobin__last__last_12h.describe()
# Out:
# count     18040.000000
# mean        231.373671
# std       14889.187299
# min           2.800000
# 25%           8.100000
# 50%           9.300000
# 75%          10.900000
# max      999999.000000
# Name: hemoglobin__last__last_12h, dtype: float64

# %%
def mask_sentinels(df, vars_to_clean, lower=0, upper=1e4):
    """
    Returns a copy of df where any value in vars_to_clean below 'lower'
    or above 'upper' is set to NaN.
    """
    df_clean = df.copy()

    df_clean[vars_to_clean] = df_clean[vars_to_clean].mask(
        (df_clean[vars_to_clean] < lower) | (df_clean[vars_to_clean] > upper),
        np.nan
    )

    return df_clean
ltm_grided_clean = mask_sentinels(ltm_grided, L_to_clip)

# %%
ltm_grided_clean.hemoglobin__last__last_12h.describe()
# Out:
# count    18036.000000
# mean         9.646542
# std          1.976224
# min          2.800000
# 25%          8.100000
# 50%          9.300000
# 75%         10.900000
# max         19.799999
# Name: hemoglobin__last__last_12h, dtype: float64

# %%
def clip_mean_iqr(df, vars_to_clip, k=4):
    """
    Two-sided robust clipping: mean ± k*IQR for each variable.
    k=4 by default.
    """
    df = df.copy()
    
    for col in vars_to_clip:
        # compute summary statistics
        mean = df[col].mean()
        q1   = df[col].quantile(0.25)
        q3   = df[col].quantile(0.75)
        iqr  = q3 - q1
        
        lower = mean - k * iqr
        upper = mean + k * iqr
        
        df[col] = df[col].clip(lower=lower, upper=upper)
    
    return df
ltm_grided_clipped = clip_mean_iqr(ltm_grided_clean, L_to_clip, 4)

# %%
# Split categorical vs numerical
cat_var  = "vent_mode__last__last_12h"
num_vars = [v for v in L_confounders if v != cat_var]

# === NUMERIC VARIABLES: Density plots ===
n = len(num_vars)
cols = 4
rows = (n + cols - 1) // cols

plt.figure(figsize=(20, rows * 3))

for i, var in enumerate(num_vars, 1):
    plt.subplot(rows, cols, i)
    sns.kdeplot(data=ltm_grided_clipped, x=var, fill=True, bw_adjust=1)
    plt.title(var)
    plt.tight_layout()
plt.savefig("./numericals.pdf")
plt.show()

# === CATEGORICAL VARIABLE: Countplot ===
plt.figure(figsize=(10, 5))
sns.countplot(data=ltm_grided_clipped, x=cat_var)
plt.xticks(rotation=45)
plt.title(cat_var)
plt.tight_layout()
plt.show()
# Out:
# /home/ssimha/Data-Pipeline/BlendedICU/blended/lib/python3.10/site-packages/seaborn/categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)

# %%
ltm_grided_clipped
# Out:
#                 stay_id        grid_end  \
# 0       mimic4-30000153 0 days 12:00:00
# 1       mimic4-30000153 1 days 00:00:00
# 2       mimic4-30000153 1 days 12:00:00
# 3       mimic4-30000153 2 days 00:00:00
# 4       mimic4-30000213 0 days 12:00:00
# ...                 ...             ...
# 726804  mimic4-39999858 2 days 00:00:00
# 726805  mimic4-39999858 2 days 12:00:00
# 726806  mimic4-39999858 3 days 00:00:00
# 726807  mimic4-39999858 3 days 12:00:00
# 726808  mimic4-39999858 4 days 00:00:00
#
#         vent_mode__hours_since_last__last_12h  temperature__mean__last_12h  \
# 0                                    6.983333                    37.625000
# 1                                         NaN                    37.333332
# 2                                         NaN                    37.569443
# 3                                         NaN                          NaN
# 4                                         NaN                    36.911114
# ...                                       ...                          ...
# 726804                                    NaN                    36.944447
# 726805                                    NaN                    36.902779
# 726806                                    NaN                    36.870373
# 726807                                    NaN                    36.722225
# 726808                                    NaN                    37.222225
#
#         heart_rate__mean__last_12h  \
# 0                       109.076920
# 1                       104.416664
# 2                       102.250000
# 3                        99.666664
# 4                        78.384613
# ...                            ...
# 726804                   64.833336
# 726805                   64.250000
# 726806                   68.166664
# 726807                   64.666664
# 726808                   70.125000
#
#         arterial_blood_pressure_mean__mean__last_12h  \
# 0                                          84.380959
# 1                                          91.846153
# 2                                          95.476189
# 3                                          91.333336
# 4                                          78.846153
# ...                                              ...
# 726804                                     77.250000
# 726805                                     81.818184
# 726806                                     71.166664
# 726807                                     69.666664
# 726808                                     74.000000
#
#         fluid_out_urine__mean__last_12h  pco2_arterial__mean__last_12h  \
# 0                             82.222221                           44.0
# 1                             55.000000                            NaN
# 2                             83.125000                            NaN
# 3                             70.000000                            NaN
# 4                            324.166656                           41.5
# ...                                 ...                            ...
# 726804                              NaN                            NaN
# 726805                              NaN                            NaN
# 726806                              NaN                            NaN
# 726807                              NaN                            NaN
# 726808                              NaN                            NaN
#
#         respiratory_rate_measured__mean__last_12h  \
# 0                                       17.230770
# 1                                       12.500000
# 2                                       14.272727
# 3                                       15.333333
# 4                                       21.692308
# ...                                           ...
# 726804                                  21.500000
# 726805                                  23.916666
# 726806                                  24.500000
# 726807                                  25.666666
# 726808                                  26.750000
#
#         o2_saturation__mean__last_12h  ...  raw_weight         unit_type  \
# 0                           97.923080  ...        73.0            Trauma
# 1                           95.250000  ...        73.0            Trauma
# 2                           98.545456  ...        73.0            Trauma
# 3                          100.000000  ...        73.0            Trauma
# 4                           98.846153  ...        84.7           Medical
# ...                               ...  ...         ...               ...
# 726804                      95.166664  ...       123.8  Medical-Surgical
# 726805                      92.550003  ...       123.8  Medical-Surgical
# 726806                      93.250000  ...       123.8  Medical-Surgical
# 726807                      92.166664  ...       123.8  Medical-Surgical
# 726808                      92.875000  ...       123.8  Medical-Surgical
#
#               origin             los              intime             outtime  \
# 0          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 1          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 2          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 3          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 4              Other 1 days 15:14:48 2162-06-21 05:38:00 2162-06-22 20:52:48
# ...              ...             ...                 ...                 ...
# 726804  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726805  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726806  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726807  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 726808  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
#
#         death_time_from_intime  icu_mortality  death_abs_time  \
# 0                          NaT              0             NaT
# 1                          NaT              0             NaT
# 2                          NaT              0             NaT
# 3                          NaT              0             NaT
# 4           1363 days 18:22:00              0      2166-03-16
# ...                        ...            ...             ...
# 726804                     NaT              0             NaT
# 726805                     NaT              0             NaT
# 726806                     NaT              0             NaT
# 726807                     NaT              0             NaT
# 726808                     NaT              0             NaT
#
#        mortality_after_discharge
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 726804                         0
# 726805                         0
# 726806                         0
# 726807                         0
# 726808                         0
#
# [726809 rows x 33 columns]

# %%
baseline = ["raw_age", 
            "sex", 
            "raw_height", 
            "raw_weight", 
            "unit_type", 
            "origin"]

def fill_baseline_first_valid(df, baseline_vars):
    df_out = df.copy()

    # For each baseline variable
    for col in baseline_vars:
        # Get first non-NaN value per admission_id
        first_valid = (
            df_out.groupby("stay_id")[col]
                  .apply(lambda s: s.dropna().iloc[0] if s.dropna().size > 0 else np.nan)
        )

        # Map back to all rows
        df_out[col] = df_out["stay_id"].map(first_valid)

    return df_out
ltm_grided_clipped = fill_baseline_first_valid(ltm_grided_clipped, baseline)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 23
#      20         df_out[col] = df_out["stay_id"].map(first_valid)
#      22     return df_out
# ---> 23 ltm_grided_clipped = fill_baseline_first_valid(ltm_grided_clipped, baseline)
#
# Cell In[74], line 15, in fill_baseline_first_valid(df, baseline_vars)
#      11 # For each baseline variable
#      12 for col in baseline_vars:
#      13     # Get first non-NaN value per admission_id
#      14     first_valid = (
# ---> 15         df_out.groupby("stay_id")[col]
#      16               .apply(lambda s: s.dropna().iloc[0] if s.dropna().size > 0 else np.nan)
#      17     )
#      19     # Map back to all rows
#      20     df_out[col] = df_out["stay_id"].map(first_valid)
#
# File ~/Data-Pipeline/BlendedICU/blended/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~/Data-Pipeline/BlendedICU/blended/lib/python3.10/site-packages/pandas/core/base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
#     246     ndim = self.obj[key].ndim
#     247     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: age'

# %%
ltm_grided_clipped.to_parquet("../Dataset/mimic-iv/from_pipeline/ltm_grided_clipped.parquet")
