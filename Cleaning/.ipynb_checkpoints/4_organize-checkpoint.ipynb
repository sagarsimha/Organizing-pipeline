# %% [markdown]
# # Cleaning, clipping, cleaning sentinels

# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ltm_grided = pd.read_parquet("../Dataset/mimic-iv/from_pipeline/ltm_grided.parquet")

# %%
ltm_grided
# Out:
#                 stay_id        grid_end  \
# 0       mimic4-30000153 0 days 12:00:00
# 1       mimic4-30000153 1 days 00:00:00
# 2       mimic4-30000153 1 days 12:00:00
# 3       mimic4-30000153 2 days 00:00:00
# 4       mimic4-30000213 0 days 12:00:00
# ...                 ...             ...
# 718193  mimic4-39999858 2 days 00:00:00
# 718194  mimic4-39999858 2 days 12:00:00
# 718195  mimic4-39999858 3 days 00:00:00
# 718196  mimic4-39999858 3 days 12:00:00
# 718197  mimic4-39999858 4 days 00:00:00
#
#         vent_mode__hours_since_last__last_12h  temperature__mean__last_12h  \
# 0                                    6.983333                    37.625000
# 1                                         NaN                    37.333332
# 2                                         NaN                    37.481480
# 3                                         NaN                          NaN
# 4                                         NaN                    36.911114
# ...                                       ...                          ...
# 718193                                    NaN                    36.944447
# 718194                                    NaN                    36.902779
# 718195                                    NaN                    36.870373
# 718196                                    NaN                    36.722225
# 718197                                    NaN                    37.555557
#
#         heart_rate__mean__last_12h  \
# 0                       109.076920
# 1                       104.416664
# 2                       103.199997
# 3                              NaN
# 4                        78.384613
# ...                            ...
# 718193                   64.833336
# 718194                   64.250000
# 718195                   68.166664
# 718196                   64.666664
# 718197                   63.000000
#
#         arterial_blood_pressure_mean__mean__last_12h  \
# 0                                          84.380959
# 1                                          91.846153
# 2                                          96.722221
# 3                                                NaN
# 4                                          78.846153
# ...                                              ...
# 718193                                     77.250000
# 718194                                     81.818184
# 718195                                     71.166664
# 718196                                     69.666664
# 718197                                     74.000000
#
#         fluid_out_urine__mean__last_12h  pco2_arterial__mean__last_12h  \
# 0                             82.222221                           44.0
# 1                             55.000000                            NaN
# 2                             85.000000                            NaN
# 3                                   NaN                            NaN
# 4                            324.166656                           41.5
# ...                                 ...                            ...
# 718193                              NaN                            NaN
# 718194                              NaN                            NaN
# 718195                              NaN                            NaN
# 718196                              NaN                            NaN
# 718197                              NaN                            NaN
#
#         respiratory_rate_measured__mean__last_12h  \
# 0                                       17.230770
# 1                                       12.500000
# 2                                       15.000000
# 3                                             NaN
# 4                                       21.692308
# ...                                           ...
# 718193                                  21.500000
# 718194                                  23.916666
# 718195                                  24.500000
# 718196                                  25.666666
# 718197                                  26.600000
#
#         o2_saturation__mean__last_12h  ...  sex  raw_height  raw_weight  \
# 0                           97.923080  ...  1.0         NaN        73.0
# 1                           95.250000  ...  1.0         NaN        73.0
# 2                           98.333336  ...  1.0         NaN        73.0
# 3                                 NaN  ...  1.0         NaN        73.0
# 4                           98.846153  ...  1.0      160.01        84.7
# ...                               ...  ...  ...         ...         ...
# 718193                      95.166664  ...  1.0         NaN       123.8
# 718194                      92.550003  ...  1.0         NaN       123.8
# 718195                      93.250000  ...  1.0         NaN       123.8
# 718196                      92.166664  ...  1.0         NaN       123.8
# 718197                      94.199997  ...  1.0         NaN       123.8
#
#                unit_type        origin             los              intime  \
# 0                 Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 1                 Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 2                 Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 3                 Trauma     Emergency 1 days 15:17:10 2174-09-29 12:09:00
# 4                Medical         Other 1 days 15:14:48 2162-06-21 05:38:00
# ...                  ...           ...             ...                 ...
# 718193  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 718194  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 718195  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 718196  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
# 718197  Medical-Surgical  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00
#
#                    outtime  death_time_from_intime icu_mortality
# 0      2174-10-01 03:26:10                     NaT             0
# 1      2174-10-01 03:26:10                     NaT             0
# 2      2174-10-01 03:26:10                     NaT             0
# 3      2174-10-01 03:26:10                     NaT             0
# 4      2162-06-22 20:52:48      1363 days 18:22:00             0
# ...                    ...                     ...           ...
# 718193 2167-04-30 10:11:50                     NaT             0
# 718194 2167-04-30 10:11:50                     NaT             0
# 718195 2167-04-30 10:11:50                     NaT             0
# 718196 2167-04-30 10:11:50                     NaT             0
# 718197 2167-04-30 10:11:50                     NaT             0
#
# [718198 rows x 32 columns]

# %% [markdown]
# ## Death times

# %%
# Ensure correct dtypes
ltm_grided["intime"]  = pd.to_datetime(ltm_grided["intime"], errors="coerce")
ltm_grided["outtime"] = pd.to_datetime(ltm_grided["outtime"], errors="coerce")

# death_time_from_intime must be timedelta
ltm_grided["death_time_from_intime"] = pd.to_timedelta(
    ltm_grided["death_time_from_intime"], errors="coerce"
)

# Absolute death time = intime + death offset
ltm_grided["death_abs_time"] = ltm_grided["intime"] + ltm_grided["death_time_from_intime"]

'''# 7-day post-ICU mortality (row level)
ltm_grided["mortality_after_discharge"] = (
    ltm_grided["death_abs_time"].notna()
    & (ltm_grided["death_abs_time"] > ltm_grided["outtime"])
    & (ltm_grided["death_abs_time"] <= ltm_grided["outtime"] + pd.Timedelta(days=7))
).astype(int)'''
# Out:
# '# 7-day post-ICU mortality (row level)\nltm_grided["mortality_after_discharge"] = (\n    ltm_grided["death_abs_time"].notna()\n    & (ltm_grided["death_abs_time"] > ltm_grided["outtime"])\n    & (ltm_grided["death_abs_time"] <= ltm_grided["outtime"] + pd.Timedelta(days=7))\n).astype(int)'

# %% [markdown]
# ## Check if "Mortality" is in-icu mortality

# %% [raw]
# #ratio of mortality
# last_rows = ltm_grided.groupby("stay_id").tail(1)
# (last_rows["mortality_after_discharge"] == 1).mean()

# %% [raw]
# #ratio of icu mortality
# (last_rows["icu_mortality"] == 1).mean()

# %% [markdown]
# ## Derive icu_mortality from timestamp

# %%
ltm_grided["icu_mortality_derived"] = (
    ltm_grided["death_abs_time"].notna()
    & (ltm_grided["death_abs_time"] >= ltm_grided["intime"])
    & (ltm_grided["death_abs_time"] <= ltm_grided["outtime"])
)

# %%
#ratio of mortality
last_rows_der = ltm_grided.groupby("stay_id").tail(1)
(last_rows_der["icu_mortality_derived"] == 1).mean()
# Out:
# np.float64(0.07408539812081799)

# %% [markdown]
# ## Map to standard categories (invasive_controlled, invasive assisted etc)

# %%
ltm_grided["vent_mode__last__last_12h"]
# Out:
# 0         CPAP/PSV
# 1             None
# 2             None
# 3             None
# 4             None
#             ...
# 718193        None
# 718194        None
# 718195        None
# 718196        None
# 718197        None
# Name: vent_mode__last__last_12h, Length: 718198, dtype: object

# %%
# Mapping vent_mode__last__last_12h from raw categories → derived categories
vent_mode_map = {
    "SPONT": "invasive_assisted",
    "CMV/ASSIST/AutoFlow": "invasive_controlled",
    "PSV/SBT": "invasive_assisted",
    "CMV/ASSIST": "invasive_controlled",
    "invasive_assisted": "invasive_assisted",
    "APV (cmv)": "invasive_controlled",
    "invasive_controlled": "invasive_controlled",
    "CPAP/PSV+ApnVol": "invasive_assisted",
    "SIMV/PSV/AutoFlow": "invasive_controlled",
    "CMV/AutoFlow": "invasive_controlled",
    "Spontaneous (S)": "invasive_assisted",
    "PCV+Assist": "invasive_controlled",
    "(S) CMV": "invasive_controlled",
    "Not applicable": "cancelled",
    "MMV/PSV/AutoFlow": "invasive_assisted",
    "PCV+": "invasive_controlled",
    "MMV/PSV": "invasive_assisted",
    "niv_unknown": "niv_unknown",
    "CPAP/PSV+ApnPres": "invasive_assisted",
    "PRES/AC": "invasive_controlled",
    "APRV/Biphasic+ApnVol": "invasive_controlled",
    "SIMV/PSV": "invasive_controlled",
    "CMV": "invasive_controlled",
    "Spontaneous/Timed (S/T) (Back up)": "cancelled",
    "VOL/AC": "invasive_controlled",
    "PCV+/PSV": "invasive_controlled",
    "SIMV/PRES": "invasive_controlled",
    "Apnea Ventilation": "cancelled",
    "niv_assisted": "niv_assisted",
    "APV (simv)": "invasive_controlled",
    "SYNCHRON MASTER": "cancelled",
    "SIMV/VOL": "invasive_controlled",
    "PRVC/SIMV": "invasive_controlled",
    "APRV/Biphasic+ApnPress": "invasive_controlled",
    "MMV/AutoFlow": "invasive_assisted",
    "P-SIMV": "invasive_controlled",
    "Timed (T)": "cancelled",
    "CPAP/PSV+Apn TCPL": "invasive_assisted",
    "SYNCHRON SLAVE": "cancelled",
    "DuoPaP": "invasive_assisted",
    "nCPAP-PS": "niv_assisted",
    "Standby": "invasive_assisted"
}
ltm_grided["vent_mode__last__last_12h"] = ltm_grided["vent_mode__last__last_12h"].map(vent_mode_map)

# %%
ltm_grided["vent_mode__last__last_12h"] = ltm_grided["vent_mode__last__last_12h"].fillna("unknown")

# %%
ltm_grided["vent_mode__last__last_12h"].value_counts(dropna=False)
# Out:
# vent_mode__last__last_12h
# unknown                640013
# invasive_controlled     58103
# invasive_assisted       20034
# cancelled                  48
# Name: count, dtype: int64

# %% [markdown]
# ## Check min, max and distributions (density plot)

# %%
# Load mappings.json
with open("mappings.json", "r") as f:
    mappings = json.load(f)
L_confounders = list(mappings.values()) + ["vent_mode__hours_since_last__last_12h"]

# %%
L_confounders
# Out:
# ['bicarbonate_arterial__last__last_12h',
#  'activated_partial_thromboplastin_time__last__last_12h',
#  'temperature__mean__last_12h',
#  'hemoglobin__last__last_12h',
#  'heart_rate__mean__last_12h',
#  'arterial_blood_pressure_mean__mean__last_12h',
#  'creatinine__last__last_12h',
#  'ureum__last__last_12h',
#  'fluid_out_urine__mean__last_12h',
#  'lactate__last__last_12h',
#  'glasgow_coma_scale_total__last__last_12h',
#  'pco2_arterial__mean__last_12h',
#  'respiratory_rate_measured__mean__last_12h',
#  'o2_saturation__mean__last_12h',
#  'fio2__last__last_12h',
#  'po2_arterial__mean__last_12h',
#  'vent_mode__last__last_12h',
#  'vent_mode__hours_since_last__last_12h']

# %%
L_to_clip = [
 'bicarbonate_arterial__last__last_12h',
 'activated_partial_thromboplastin_time__last__last_12h',
 'temperature__mean__last_12h',
 'hemoglobin__last__last_12h',
 'heart_rate__mean__last_12h',
 'arterial_blood_pressure_mean__mean__last_12h',
 'creatinine__last__last_12h',
 'ureum__last__last_12h',
 'fluid_out_urine__mean__last_12h',
 'lactate__last__last_12h',
 #'glasgow_coma_scale_total__last__last_12h',
 'pco2_arterial__mean__last_12h',
 'respiratory_rate_measured__mean__last_12h',
 'o2_saturation__mean__last_12h',
 #'fio2__last__last_12h',
 'po2_arterial__mean__last_12h',
 #'vent_mode__last__last_12h',
 #'vent_mode__hours_since_last__last_12h'
 ]

# %% [raw]
# def mask_sentinels(df, vars_to_clean, lower=0, upper=1e4):
#     """
#     Returns a copy of df where any value in vars_to_clean below 'lower'
#     or above 'upper' is set to NaN.
#     """
#     df_clean = df.copy()
#
#     df_clean[vars_to_clean] = df_clean[vars_to_clean].mask(
#         (df_clean[vars_to_clean] < lower) | (df_clean[vars_to_clean] > upper),
#         np.nan
#     )
#
#     return df_clean
# ltm_grided = mask_sentinels(ltm_grided, L_to_clip)

# %% [markdown]
# ## 4*IQR based clipping

# %% [raw]
# def clip_mean_iqr(df, vars_to_clip, k=4):
#     """
#     Two-sided robust clipping: mean ± k*IQR for each variable.
#     k=4 by default.
#     """
#     df = df.copy()
#
#     for col in vars_to_clip:
#         # compute summary statistics
#         mean = df[col].mean()
#         q1   = df[col].quantile(0.25)
#         q3   = df[col].quantile(0.75)
#         iqr  = q3 - q1
#
#         lower = mean - k * iqr
#         upper = mean + k * iqr
#
#         df[col] = df[col].clip(lower=lower, upper=upper)
#
#     return df
# ltm_grided_clipped = clip_mean_iqr(ltm_grided, L_to_clip, 4)

# %% [markdown]
# ## Clinically meaningful clipping
# #### 1. Physiology possible range
# #### 2. ICU-plausible range
#
# ### Clinical logic to use:
# #### Temperature, SpO₂, FiO₂, HR, RR, MAP: bounded by physiology/monitoring, so clipping can be fairly rule-based.
# #### Lactate, creatinine, ureum, aPTT, PaO₂: real ICU extremes can be very high, so upper clipping must be conservative.
# #### Urine output: zero can be real; very high values often reflect documentation/binning issues, so this needs special handling.
# #### ABG variables (bicarbonate, PaCO₂, PaO₂): use broad ICU-plausible limits, not normal outpatient ranges. Normal adult ABG reference values are roughly HCO₃⁻ 22–26 mEq/L, PaCO₂ 35–45 mmHg, PaO₂ 80–100 mmHg, but clipping should be much wider in ICU data.
#
# Preprocessign rule:
# 1. Sentinel/Unit errors -> NA
# 2. Impossible values -> NA
# 3. Severe but plausible ICU values -> Keep. But, define a clinical boundary. Beyond which declare missing (NA). Techniques like MICE can be applied

# %%
# "set_missing": values outside bounds -> NaN
# "clip": values outside bounds -> truncated to boundary

CLIP_RULES = {
    "bicarbonate_arterial__last__last_12h": {
        "lower": 5.0, "upper": 50.0, "action": "set_missing",
        "unit": "mEq/L", "note": "Broad ICU-plausible bicarbonate range."
    },
    "activated_partial_thromboplastin_time__last__last_12h": {
        "lower": 18.0, "upper": 150.0, "action": "set_missing",
        "unit": "sec", "note": "Keep prolonged PTT but remove implausible values."
    },
    "temperature__mean__last_12h": {
        "lower": 30.0, "upper": 43.0, "action": "set_missing",
        "unit": "C", "note": "Outside this is almost certainly artifact/sentinel."
    },
    "hemoglobin__last__last_12h": {
        "lower": 2.5, "upper": 25.0, "action": "set_missing",
        "unit": "g/dL", "note": "Absurd or Extreme values likely unit or extraction errors."
    },
    "heart_rate__mean__last_12h": {
        "lower": 25.0, "upper": 220.0, "action": "set_missing",
        "unit": "bpm", "note": "Keep severe brady/tachycardia, remove impossible monitor artifacts."
    },
    "arterial_blood_pressure_mean__mean__last_12h": {
        "lower": 20.0, "upper": 180.0, "action": "set_missing",
        "unit": "mmHg", "note": "Broad ICU MAP range."
    },
    "creatinine__last__last_12h": {
        "lower": 0.0, "upper": 1500.0, "action": "set_missing",
        "unit": "umol/L", "note": "For µmol/L scale"
    },
    "ureum__last__last_12h": {
        "lower": 0.3, "upper": 80.0, "action": "set_missing",
        "unit": "mmol/L", "note": "Long right tail can be real in ICU."
    },
    "fluid_out_urine__mean__last_12h": {
        "lower": 0.0, "upper": 2500.0, "action": "set_missing",
        "unit": "aggregated urine metric", "note": "Zero is real, negatives are not."
    },
    "lactate__last__last_12h": {
        "lower": 0.3, "upper": 25.0, "action": "set_missing",
        "unit": "mmol/L", "note": "Preserve real ICU hyperlactatemia."
    },
    "pco2_arterial__mean__last_12h": {
        "lower": 10.0, "upper": 150.0, "action": "set_missing",
        "unit": "mmHg", "note": "0 and extreme values likely artifact."
    },
    "respiratory_rate_measured__mean__last_12h": {
        "lower": 4.0, "upper": 80.0, "action": "set_missing",
        "unit": "breaths/min", "note": "Retain severe RR, remove impossible values."
    },
    "o2_saturation__mean__last_12h": {
        "lower": 50.0, "upper": 100.0, "action": "set_missing",
        "unit": "%", "note": "Bounded by definition."
    },
    "fio2__last__last_12h": {
        "lower": 21.0, "upper": 100.0, "action": "set_missing",
        "unit": "%", "note": "FiO2 as percent, not fraction."
    },
    "po2_arterial__mean__last_12h": {
        "lower": 20.0, "upper": 500.0, "action": "set_missing",
        "unit": "mmHg", "note": "Keep hyperoxia but trim implausible far tail."
    },
}

# %%
def apply_clinical_clipping(df, clip_rules, verbose=True):
    """
    Apply variable-specific clipping / invalid-value-to-missing rules.

    Returns
    -------
    df_out : pd.DataFrame
        Cleaned dataframe
    audit_df : pd.DataFrame
        Summary of what was changed per variable
    """
    df_out = df.copy()
    audit_rows = []

    for var, rule in clip_rules.items():
        if var not in df_out.columns:
            audit_rows.append({
                "variable": var,
                "present": False,
                "action": rule["action"],
                "lower": rule["lower"],
                "upper": rule["upper"],
                "n_nonmissing_before": np.nan,
                "n_below": np.nan,
                "n_above": np.nan,
                "n_changed": np.nan,
                "n_nonmissing_after": np.nan,
            })
            continue

        s = pd.to_numeric(df_out[var], errors="coerce")
        lower, upper = rule["lower"], rule["upper"]
        action = rule["action"]

        below = s < lower
        above = s > upper
        outside = below | above

        n_nonmissing_before = int(s.notna().sum())
        n_below = int(below.sum())
        n_above = int(above.sum())

        s_new = s.copy()

        if action == "set_missing":
            s_new[outside] = np.nan
        elif action == "clip":
            s_new = s_new.clip(lower=lower, upper=upper)
        else:
            raise ValueError(f"Unknown action '{action}' for {var}")

        n_changed = int((s_new != s).fillna(False).sum() + ((s.isna()) != (s_new.isna())).sum())
        n_nonmissing_after = int(s_new.notna().sum())

        df_out[var] = s_new

        audit_rows.append({
            "variable": var,
            "present": True,
            "action": action,
            "lower": lower,
            "upper": upper,
            "unit": rule.get("unit"),
            "note": rule.get("note"),
            "n_nonmissing_before": n_nonmissing_before,
            "n_below": n_below,
            "n_above": n_above,
            "n_outside_total": int(outside.sum()),
            "n_changed": n_changed,
            "n_nonmissing_after": n_nonmissing_after,
        })

        if verbose:
            print(
                f"{var}: action={action}, below={n_below}, above={n_above}, "
                f"nonmissing_before={n_nonmissing_before}, nonmissing_after={n_nonmissing_after}"
            )

    audit_df = pd.DataFrame(audit_rows)
    return df_out, audit_df

# %%
ltm_grided_clipped, clipping_audit = apply_clinical_clipping(
    ltm_grided,
    CLIP_RULES,
    verbose=True
)

display(clipping_audit)
# Out:
# bicarbonate_arterial__last__last_12h: action=clip, below=0, above=0, nonmissing_before=17317, nonmissing_after=17317
# activated_partial_thromboplastin_time__last__last_12h: action=clip, below=0, above=0, nonmissing_before=11308, nonmissing_after=11308
# temperature__mean__last_12h: action=set_missing, below=558, above=101, nonmissing_before=616207, nonmissing_after=615548
# hemoglobin__last__last_12h: action=set_missing, below=0, above=4, nonmissing_before=17356, nonmissing_after=17352
# heart_rate__mean__last_12h: action=set_missing, below=33, above=17, nonmissing_before=677969, nonmissing_after=677919
# arterial_blood_pressure_mean__mean__last_12h: action=set_missing, below=31, above=209, nonmissing_before=661140, nonmissing_after=660900
# creatinine__last__last_12h: action=clip, below=0, above=5, nonmissing_before=17344, nonmissing_after=17344
# ureum__last__last_12h: action=clip, below=0, above=0, nonmissing_before=17329, nonmissing_after=17329
# fluid_out_urine__mean__last_12h: action=clip, below=2, above=18, nonmissing_before=437340, nonmissing_after=437340
# lactate__last__last_12h: action=clip, below=0, above=2, nonmissing_before=9562, nonmissing_after=9562
# pco2_arterial__mean__last_12h: action=set_missing, below=4, above=8, nonmissing_before=233995, nonmissing_after=233983
# respiratory_rate_measured__mean__last_12h: action=set_missing, below=122, above=41, nonmissing_before=674255, nonmissing_after=674092
# o2_saturation__mean__last_12h: action=set_missing, below=75, above=0, nonmissing_before=676201, nonmissing_after=676126
# fio2__last__last_12h: action=set_missing, below=193, above=3, nonmissing_before=46634, nonmissing_after=46438
# po2_arterial__mean__last_12h: action=clip, below=178, above=59, nonmissing_before=234079, nonmissing_after=234079
#                                              variable  present       action  \
# 0                bicarbonate_arterial__last__last_12h     True         clip
# 1   activated_partial_thromboplastin_time__last__l...     True         clip
# 2                         temperature__mean__last_12h     True  set_missing
# 3                          hemoglobin__last__last_12h     True  set_missing
# 4                          heart_rate__mean__last_12h     True  set_missing
# 5        arterial_blood_pressure_mean__mean__last_12h     True  set_missing
# 6                          creatinine__last__last_12h     True         clip
# 7                               ureum__last__last_12h     True         clip
# 8                     fluid_out_urine__mean__last_12h     True         clip
# 9                             lactate__last__last_12h     True         clip
# 10                      pco2_arterial__mean__last_12h     True  set_missing
# 11          respiratory_rate_measured__mean__last_12h     True  set_missing
# 12                      o2_saturation__mean__last_12h     True  set_missing
# 13                               fio2__last__last_12h     True  set_missing
# 14                       po2_arterial__mean__last_12h     True         clip
#
#     lower   upper                     unit  \
# 0     5.0    50.0                    mEq/L
# 1    18.0   150.0                      sec
# 2    30.0    43.0                        C
# 3     2.5    25.0                     g/dL
# 4    25.0   220.0                      bpm
# 5    20.0   180.0                     mmHg
# 6     0.0  1500.0                   umol/L
# 7     0.3    80.0                   mmol/L
# 8     0.0  2500.0  aggregated urine metric
# 9     0.3    25.0                   mmol/L
# 10   10.0   150.0                     mmHg
# 11    4.0    80.0              breaths/min
# 12   50.0   100.0                        %
# 13   21.0   100.0                        %
# 14   20.0   500.0                     mmHg
#
#                                                  note  n_nonmissing_before  \
# 0              Broad ICU-plausible bicarbonate range.                17317
# 1   Keep prolonged PTT but remove implausible values.                11308
# 2   Outside this is almost certainly artifact/sent...               616207
# 3   Absurd or Extreme values likely unit or extrac...                17356
# 4   Keep severe brady/tachycardia, remove impossib...               677969
# 5                                Broad ICU MAP range.               661140
# 6                                    For µmol/L scale                17344
# 7                 Long right tail can be real in ICU.                17329
# 8                    Zero is real, negatives are not.               437340
# 9                  Preserve real ICU hyperlactatemia.                 9562
# 10              0 and extreme values likely artifact.               233995
# 11        Retain severe RR, remove impossible values.               674255
# 12                             Bounded by definition.               676201
# 13                     FiO2 as percent, not fraction.                46634
# 14      Keep hyperoxia but trim implausible far tail.               234079
#
#     n_below  n_above  n_outside_total  n_changed  n_nonmissing_after
# 0         0        0                0     700881               17317
# 1         0        0                0     706890               11308
# 2       558      101              659     103309              615548
# 3         0        4                4     700850               17352
# 4        33       17               50      40329              677919
# 5        31      209              240      57538              660900
# 6         0        5                5     700859               17344
# 7         0        0                0     700869               17329
# 8         2       18               20     280878              437340
# 9         0        2                2     708638                9562
# 10        4        8               12     484227              233983
# 11      122       41              163      44269              674092
# 12       75        0               75      42147              676126
# 13      193        3              196     671956               46438
# 14      178       59              237     484356              234079

# %%
def compare_before_after(df_before, df_after, variables, ncols=2, bins=60):
    for var in variables:
        if var not in df_before.columns or var not in df_after.columns:
            continue

        x_before = pd.to_numeric(df_before[var], errors="coerce").dropna()
        x_after = pd.to_numeric(df_after[var], errors="coerce").dropna()

        fig, axes = plt.subplots(1, 2, figsize=(12, 4))

        axes[0].hist(x_before, bins=bins)
        axes[0].set_title(f"{var} - before")

        axes[1].hist(x_after, bins=bins)
        axes[1].set_title(f"{var} - after")

        plt.tight_layout()
        plt.show()

compare_before_after(ltm_grided, ltm_grided_clipped, list(CLIP_RULES.keys()))

# %% [markdown]
# # Converting fio2 and GCS into ordinal bins

# %%
# Modify fio2__last__last_12h
def transform_fio2_to_ordered_bins(df, col="fio2__last__last_12h"):
    df = df.copy()

    # Only valid after clipping to [21, 100]
    bins = [21, 30, 40, 50, 60, 80, 100]
    labels = [
        "21_30",
        "31_40",
        "41_50",
        "51_60",
        "61_80",
        "81_100"
    ]

    df[col] = pd.cut(
        df[col],
        bins=bins,
        labels=labels,
        include_lowest=True,
        ordered=True
    )

    # Add missing categories
    #df[col] = df[col].cat.add_categories(["missing"])
    #df[col] = df[col].fillna("missing")

    return df

ltm_grided_clipped = transform_fio2_to_ordered_bins(ltm_grided_clipped)

# %%
print(ltm_grided_clipped["fio2__last__last_12h"].dtype)
print(ltm_grided_clipped["fio2__last__last_12h"].cat.categories)
print(ltm_grided_clipped["fio2__last__last_12h"].value_counts(dropna=False))
# Out:
# category
# Index(['21_30', '31_40', '41_50', '51_60', '61_80', '81_100'], dtype='object')
# fio2__last__last_12h
# NaN       671760
# 31_40      21380
# 41_50      12312
# 21_30       4422
# 51_60       3439
# 61_80       2784
# 81_100      2101
# Name: count, dtype: int64

# %%
def transform_gcs_to_4bins(df, col="glasgow_coma_scale_total__last__last_12h"):
    df = df.copy()

    # Define bins
    bins = [-np.inf, 8, 12, 14, 15]
    labels = [
        "severe",          # 3–8
        "moderate",        # 9–12
        "mild_impaired",   # 13–14
        "normal"           # 15
    ]

    # Apply ordered categorical binning
    df[col] = pd.cut(
        df[col],
        bins=bins,
        labels=labels,
        ordered=True,
        right=True  # include upper bound
    )

    return df
ltm_grided_clipped = transform_gcs_to_4bins(ltm_grided_clipped)

# %%
print(ltm_grided_clipped["glasgow_coma_scale_total__last__last_12h"].dtype)
print(ltm_grided_clipped["glasgow_coma_scale_total__last__last_12h"].cat.categories)
print(ltm_grided_clipped["glasgow_coma_scale_total__last__last_12h"].value_counts(dropna=False))
# Out:
# category
# Index(['severe', 'moderate', 'mild_impaired', 'normal'], dtype='object')
# glasgow_coma_scale_total__last__last_12h
# NaN              625352
# normal            36642
# moderate          22170
# severe            20048
# mild_impaired     13986
# Name: count, dtype: int64

# %% [markdown]
# # Plotting distributions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Define variables
# -----------------------------
cat_vars = [
    "vent_mode__last__last_12h",
    "fio2__last__last_12h",
    "glasgow_coma_scale_total__last__last_12h"
]

num_vars = [v for v in L_confounders if v not in cat_vars]

# -----------------------------
# NUMERIC VARIABLES: KDE plots
# -----------------------------
n = len(num_vars)
cols = 4
rows = (n + cols - 1) // cols

plt.figure(figsize=(20, rows * 3))

for i, var in enumerate(num_vars, 1):
    plt.subplot(rows, cols, i)
    
    sns.kdeplot(
        data=ltm_grided_clipped,
        x=var,
        fill=True,
        bw_adjust=1
    )
    
    plt.title(var)

plt.tight_layout()
plt.savefig("./numericals.pdf")
plt.show()


# -----------------------------
# CATEGORICAL VARIABLES: Countplots
# -----------------------------
n_cat = len(cat_vars)
cols = 2
rows = (n_cat + cols - 1) // cols

plt.figure(figsize=(12, rows * 4))

for i, var in enumerate(cat_vars, 1):
    plt.subplot(rows, cols, i)
    
    # Ensure consistent ordering for ordinal variables
    order = sorted(ltm_grided_clipped[var].dropna().unique())
    
    sns.countplot(
        data=ltm_grided_clipped,
        x=var,
        order=order
    )
    
    plt.xticks(rotation=45)
    plt.title(var)

plt.tight_layout()
plt.savefig("./categoricals.pdf")
plt.show()

# %%
ltm_grided_clipped
# Out:
#                 stay_id        grid_end  \
# 0       mimic4-30000153 0 days 12:00:00
# 1       mimic4-30000153 1 days 00:00:00
# 2       mimic4-30000153 1 days 12:00:00
# 3       mimic4-30000153 2 days 00:00:00
# 4       mimic4-30000213 0 days 12:00:00
# ...                 ...             ...
# 718193  mimic4-39999858 2 days 00:00:00
# 718194  mimic4-39999858 2 days 12:00:00
# 718195  mimic4-39999858 3 days 00:00:00
# 718196  mimic4-39999858 3 days 12:00:00
# 718197  mimic4-39999858 4 days 00:00:00
#
#         vent_mode__hours_since_last__last_12h  temperature__mean__last_12h  \
# 0                                    6.983333                    37.625000
# 1                                         NaN                    37.333332
# 2                                         NaN                    37.481480
# 3                                         NaN                          NaN
# 4                                         NaN                    36.911114
# ...                                       ...                          ...
# 718193                                    NaN                    36.944447
# 718194                                    NaN                    36.902779
# 718195                                    NaN                    36.870373
# 718196                                    NaN                    36.722225
# 718197                                    NaN                    37.555557
#
#         heart_rate__mean__last_12h  \
# 0                       109.076920
# 1                       104.416664
# 2                       103.199997
# 3                              NaN
# 4                        78.384613
# ...                            ...
# 718193                   64.833336
# 718194                   64.250000
# 718195                   68.166664
# 718196                   64.666664
# 718197                   63.000000
#
#         arterial_blood_pressure_mean__mean__last_12h  \
# 0                                          84.380959
# 1                                          91.846153
# 2                                          96.722221
# 3                                                NaN
# 4                                          78.846153
# ...                                              ...
# 718193                                     77.250000
# 718194                                     81.818184
# 718195                                     71.166664
# 718196                                     69.666664
# 718197                                     74.000000
#
#         fluid_out_urine__mean__last_12h  pco2_arterial__mean__last_12h  \
# 0                             82.222221                           44.0
# 1                             55.000000                            NaN
# 2                             85.000000                            NaN
# 3                                   NaN                            NaN
# 4                            324.166656                           41.5
# ...                                 ...                            ...
# 718193                              NaN                            NaN
# 718194                              NaN                            NaN
# 718195                              NaN                            NaN
# 718196                              NaN                            NaN
# 718197                              NaN                            NaN
#
#         respiratory_rate_measured__mean__last_12h  \
# 0                                       17.230770
# 1                                       12.500000
# 2                                       15.000000
# 3                                             NaN
# 4                                       21.692308
# ...                                           ...
# 718193                                  21.500000
# 718194                                  23.916666
# 718195                                  24.500000
# 718196                                  25.666666
# 718197                                  26.600000
#
#         o2_saturation__mean__last_12h  ...  raw_weight         unit_type  \
# 0                           97.923080  ...        73.0            Trauma
# 1                           95.250000  ...        73.0            Trauma
# 2                           98.333336  ...        73.0            Trauma
# 3                                 NaN  ...        73.0            Trauma
# 4                           98.846153  ...        84.7           Medical
# ...                               ...  ...         ...               ...
# 718193                      95.166664  ...       123.8  Medical-Surgical
# 718194                      92.550003  ...       123.8  Medical-Surgical
# 718195                      93.250000  ...       123.8  Medical-Surgical
# 718196                      92.166664  ...       123.8  Medical-Surgical
# 718197                      94.199997  ...       123.8  Medical-Surgical
#
#               origin             los              intime             outtime  \
# 0          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 1          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 2          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 3          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 4              Other 1 days 15:14:48 2162-06-21 05:38:00 2162-06-22 20:52:48
# ...              ...             ...                 ...                 ...
# 718193  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718194  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718195  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718196  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718197  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
#
#         death_time_from_intime icu_mortality death_abs_time  \
# 0                          NaT             0            NaT
# 1                          NaT             0            NaT
# 2                          NaT             0            NaT
# 3                          NaT             0            NaT
# 4           1363 days 18:22:00             0     2166-03-16
# ...                        ...           ...            ...
# 718193                     NaT             0            NaT
# 718194                     NaT             0            NaT
# 718195                     NaT             0            NaT
# 718196                     NaT             0            NaT
# 718197                     NaT             0            NaT
#
#        icu_mortality_derived
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 718193                 False
# 718194                 False
# 718195                 False
# 718196                 False
# 718197                 False
#
# [718198 rows x 34 columns]

# %%
ltm_grided_clipped.columns
# Out:
# Index(['stay_id', 'grid_end', 'vent_mode__hours_since_last__last_12h',
#        'temperature__mean__last_12h', 'heart_rate__mean__last_12h',
#        'arterial_blood_pressure_mean__mean__last_12h',
#        'fluid_out_urine__mean__last_12h', 'pco2_arterial__mean__last_12h',
#        'respiratory_rate_measured__mean__last_12h',
#        'o2_saturation__mean__last_12h', 'po2_arterial__mean__last_12h',
#        'bicarbonate_arterial__last__last_12h',
#        'activated_partial_thromboplastin_time__last__last_12h',
#        'hemoglobin__last__last_12h', 'creatinine__last__last_12h',
#        'ureum__last__last_12h', 'lactate__last__last_12h',
#        'glasgow_coma_scale_total__last__last_12h', 'fio2__last__last_12h',
#        'vent_mode__last__last_12h', 'subject_id', 'raw_age', 'sex',
#        'raw_height', 'raw_weight', 'unit_type', 'origin', 'los', 'intime',
#        'outtime', 'death_time_from_intime', 'icu_mortality', 'death_abs_time',
#        'icu_mortality_derived'],
#       dtype='object')

# %%
ltm_grided_clipped.stay_id.nunique()
# Out:
# 85037

# %%
baseline = ["raw_age", 
            "sex", 
            "raw_height", 
            "raw_weight", 
            "unit_type", 
            "origin",
            "subject_id"]

def fill_baseline_first_valid(df, baseline_vars):
    df_out = df.copy()

    # For each baseline variable
    for col in baseline_vars:
        # Get first non-NaN value per admission_id
        first_valid = (
            df_out.groupby("stay_id")[col]
                  .apply(lambda s: s.dropna().iloc[0] if s.dropna().size > 0 else np.nan)
        )

        # Map back to all rows
        df_out[col] = df_out["stay_id"].map(first_valid)

    return df_out
ltm_grided_clipped = fill_baseline_first_valid(ltm_grided_clipped, baseline)

# %%
ltm_grided_clipped.subject_id
# Out:
# 0         12466550
# 1         12466550
# 2         12466550
# 3         12466550
# 4         13180007
#             ...
# 718193    10826461
# 718194    10826461
# 718195    10826461
# 718196    10826461
# 718197    10826461
# Name: subject_id, Length: 718198, dtype: object

# %%
ltm_grided_clipped.to_parquet("../Dataset/mimic-iv/from_pipeline/ltm_grided_clipped.parquet")
