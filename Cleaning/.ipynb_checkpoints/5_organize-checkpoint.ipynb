# %% [markdown]
# # Cleaning:
# 1. Remove admission_ids which have both icu_mortality and mortality_after_discharge as True
# 3. [Done before gridding which is more appropriate] Remove row in each admission which are very close (<=5 hrs) to discharge. This is to avoid data leakage on discharge decision. Check if this can be done at 3_organizing pipeline.
# 4. Add A, D
# 5. Add Y (All-cause mortality - in-icu mortality or mortality after discharge)

# %%
import pandas as pd
import numpy as np

# %%
sf_mimicdata = pd.read_parquet('../Dataset/mimic-iv/from_pipeline/ltm_grided_clipped.parquet')
#sf_mimicdata = pd.read_parquet('../Dataset/mimic-iv/from_pipeline/leakage_rem_after_gridding__ltm_grided_clipped.parquet')

# %%
sf_mimicdata
# Out:
#                 stay_id        grid_end  \
# 0       mimic4-30000153 0 days 12:00:00
# 1       mimic4-30000153 1 days 00:00:00
# 2       mimic4-30000153 1 days 12:00:00
# 3       mimic4-30000153 2 days 00:00:00
# 4       mimic4-30000213 0 days 12:00:00
# ...                 ...             ...
# 718193  mimic4-39999858 2 days 00:00:00
# 718194  mimic4-39999858 2 days 12:00:00
# 718195  mimic4-39999858 3 days 00:00:00
# 718196  mimic4-39999858 3 days 12:00:00
# 718197  mimic4-39999858 4 days 00:00:00
#
#         vent_mode__hours_since_last__last_12h  temperature__mean__last_12h  \
# 0                                    6.983333                    37.625000
# 1                                         NaN                    37.333332
# 2                                         NaN                    37.481480
# 3                                         NaN                          NaN
# 4                                         NaN                    36.911114
# ...                                       ...                          ...
# 718193                                    NaN                    36.944447
# 718194                                    NaN                    36.902779
# 718195                                    NaN                    36.870373
# 718196                                    NaN                    36.722225
# 718197                                    NaN                    37.555557
#
#         heart_rate__mean__last_12h  \
# 0                       109.076920
# 1                       104.416664
# 2                       103.199997
# 3                              NaN
# 4                        78.384613
# ...                            ...
# 718193                   64.833336
# 718194                   64.250000
# 718195                   68.166664
# 718196                   64.666664
# 718197                   63.000000
#
#         arterial_blood_pressure_mean__mean__last_12h  \
# 0                                          84.380959
# 1                                          91.846153
# 2                                          96.722221
# 3                                                NaN
# 4                                          78.846153
# ...                                              ...
# 718193                                     77.250000
# 718194                                     81.818184
# 718195                                     71.166664
# 718196                                     69.666664
# 718197                                     74.000000
#
#         fluid_out_urine__mean__last_12h  pco2_arterial__mean__last_12h  \
# 0                             82.222221                           44.0
# 1                             55.000000                            NaN
# 2                             85.000000                            NaN
# 3                                   NaN                            NaN
# 4                            324.166656                           41.5
# ...                                 ...                            ...
# 718193                              NaN                            NaN
# 718194                              NaN                            NaN
# 718195                              NaN                            NaN
# 718196                              NaN                            NaN
# 718197                              NaN                            NaN
#
#         respiratory_rate_measured__mean__last_12h  \
# 0                                       17.230770
# 1                                       12.500000
# 2                                       15.000000
# 3                                             NaN
# 4                                       21.692308
# ...                                           ...
# 718193                                  21.500000
# 718194                                  23.916666
# 718195                                  24.500000
# 718196                                  25.666666
# 718197                                  26.600000
#
#         o2_saturation__mean__last_12h  ...  raw_weight         unit_type  \
# 0                           97.923080  ...        73.0            Trauma
# 1                           95.250000  ...        73.0            Trauma
# 2                           98.333336  ...        73.0            Trauma
# 3                                 NaN  ...        73.0            Trauma
# 4                           98.846153  ...        84.7           Medical
# ...                               ...  ...         ...               ...
# 718193                      95.166664  ...       123.8  Medical-Surgical
# 718194                      92.550003  ...       123.8  Medical-Surgical
# 718195                      93.250000  ...       123.8  Medical-Surgical
# 718196                      92.166664  ...       123.8  Medical-Surgical
# 718197                      94.199997  ...       123.8  Medical-Surgical
#
#               origin             los              intime             outtime  \
# 0          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 1          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 2          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 3          Emergency 1 days 15:17:10 2174-09-29 12:09:00 2174-10-01 03:26:10
# 4              Other 1 days 15:14:48 2162-06-21 05:38:00 2162-06-22 20:52:48
# ...              ...             ...                 ...                 ...
# 718193  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718194  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718195  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718196  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
# 718197  Direct Admit 3 days 21:35:50 2167-04-26 12:36:00 2167-04-30 10:11:50
#
#         death_time_from_intime icu_mortality death_abs_time  \
# 0                          NaT             0            NaT
# 1                          NaT             0            NaT
# 2                          NaT             0            NaT
# 3                          NaT             0            NaT
# 4           1363 days 18:22:00             0     2166-03-16
# ...                        ...           ...            ...
# 718193                     NaT             0            NaT
# 718194                     NaT             0            NaT
# 718195                     NaT             0            NaT
# 718196                     NaT             0            NaT
# 718197                     NaT             0            NaT
#
#        icu_mortality_derived
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 718193                 False
# 718194                 False
# 718195                 False
# 718196                 False
# 718197                 False
#
# [718198 rows x 34 columns]

# %%
sf_mimicdata["timestep"] = (
    sf_mimicdata.sort_values(["stay_id", "grid_end"])
              .groupby("stay_id")
              .cumcount()
)

# %%
sf_mimicdata = sf_mimicdata.rename(columns={"timestep": "t"})

# %%
sf_mimicdata.columns
# Out:
# Index(['stay_id', 'grid_end', 'vent_mode__hours_since_last__last_12h',
#        'temperature__mean__last_12h', 'heart_rate__mean__last_12h',
#        'arterial_blood_pressure_mean__mean__last_12h',
#        'fluid_out_urine__mean__last_12h', 'pco2_arterial__mean__last_12h',
#        'respiratory_rate_measured__mean__last_12h',
#        'o2_saturation__mean__last_12h', 'po2_arterial__mean__last_12h',
#        'bicarbonate_arterial__last__last_12h',
#        'activated_partial_thromboplastin_time__last__last_12h',
#        'hemoglobin__last__last_12h', 'creatinine__last__last_12h',
#        'ureum__last__last_12h', 'lactate__last__last_12h',
#        'glasgow_coma_scale_total__last__last_12h', 'fio2__last__last_12h',
#        'vent_mode__last__last_12h', 'subject_id', 'raw_age', 'sex',
#        'raw_height', 'raw_weight', 'unit_type', 'origin', 'los', 'intime',
#        'outtime', 'death_time_from_intime', 'icu_mortality', 'death_abs_time',
#        'icu_mortality_derived', 't'],
#       dtype='object')

# %%
sf_mimicdata = sf_mimicdata.sort_values(by=['stay_id', 't'])

# %%
sf_mimicdata.stay_id.nunique()
# Out:
# 85037

# %%
nan_columns = sf_mimicdata.columns[sf_mimicdata.isna().all()].tolist()
nan_columns
# Out:
# []

# %%
#mimicdata = mimicdata.drop(columns=nan_columns)

# %%
sf_mimicdata.columns
# Out:
# Index(['stay_id', 'grid_end', 'vent_mode__hours_since_last__last_12h',
#        'temperature__mean__last_12h', 'heart_rate__mean__last_12h',
#        'arterial_blood_pressure_mean__mean__last_12h',
#        'fluid_out_urine__mean__last_12h', 'pco2_arterial__mean__last_12h',
#        'respiratory_rate_measured__mean__last_12h',
#        'o2_saturation__mean__last_12h', 'po2_arterial__mean__last_12h',
#        'bicarbonate_arterial__last__last_12h',
#        'activated_partial_thromboplastin_time__last__last_12h',
#        'hemoglobin__last__last_12h', 'creatinine__last__last_12h',
#        'ureum__last__last_12h', 'lactate__last__last_12h',
#        'glasgow_coma_scale_total__last__last_12h', 'fio2__last__last_12h',
#        'vent_mode__last__last_12h', 'subject_id', 'raw_age', 'sex',
#        'raw_height', 'raw_weight', 'unit_type', 'origin', 'los', 'intime',
#        'outtime', 'death_time_from_intime', 'icu_mortality', 'death_abs_time',
#        'icu_mortality_derived', 't'],
#       dtype='object')

# %%
sf_mimicdata.head(10)
# Out:
#            stay_id        grid_end  vent_mode__hours_since_last__last_12h  \
# 0  mimic4-30000153 0 days 12:00:00                               6.983333
# 1  mimic4-30000153 1 days 00:00:00                                    NaN
# 2  mimic4-30000153 1 days 12:00:00                                    NaN
# 3  mimic4-30000153 2 days 00:00:00                                    NaN
# 4  mimic4-30000213 0 days 12:00:00                                    NaN
# 5  mimic4-30000213 1 days 00:00:00                                    NaN
# 6  mimic4-30000213 1 days 12:00:00                                    NaN
# 7  mimic4-30000213 2 days 00:00:00                                    NaN
# 8  mimic4-30000484 0 days 12:00:00                                    NaN
# 9  mimic4-30000484 1 days 00:00:00                                    NaN
#
#    temperature__mean__last_12h  heart_rate__mean__last_12h  \
# 0                    37.625000                  109.076920
# 1                    37.333332                  104.416664
# 2                    37.481480                  103.199997
# 3                          NaN                         NaN
# 4                    36.911114                   78.384613
# 5                    37.166668                   85.250000
# 6                    37.111115                   85.300003
# 7                          NaN                         NaN
# 8                    35.629631                   89.166664
# 9                    36.125000                   90.750000
#
#    arterial_blood_pressure_mean__mean__last_12h  \
# 0                                     84.380959
# 1                                     91.846153
# 2                                     96.722221
# 3                                           NaN
# 4                                     78.846153
# 5                                     79.416664
# 6                                     81.625000
# 7                                           NaN
# 8                                     64.750000
# 9                                     69.487183
#
#    fluid_out_urine__mean__last_12h  pco2_arterial__mean__last_12h  \
# 0                        82.222221                           44.0
# 1                        55.000000                            NaN
# 2                        85.000000                            NaN
# 3                              NaN                            NaN
# 4                       324.166656                           41.5
# 5                       230.000000                            NaN
# 6                       183.333328                            NaN
# 7                              NaN                            NaN
# 8                       114.000000                           59.0
# 9                        71.111115                            NaN
#
#    respiratory_rate_measured__mean__last_12h  o2_saturation__mean__last_12h  \
# 0                                  17.230770                      97.923080
# 1                                  12.500000                      95.250000
# 2                                  15.000000                      98.333336
# 3                                        NaN                            NaN
# 4                                  21.692308                      98.846153
# 5                                  16.250000                      99.083336
# 6                                  18.400000                      96.000000
# 7                                        NaN                            NaN
# 8                                  15.000000                      99.750000
# 9                                  14.416667                      99.833336
#
#    ...  unit_type     origin                    los              intime  \
# 0  ...     Trauma  Emergency        1 days 15:17:10 2174-09-29 12:09:00
# 1  ...     Trauma  Emergency        1 days 15:17:10 2174-09-29 12:09:00
# 2  ...     Trauma  Emergency        1 days 15:17:10 2174-09-29 12:09:00
# 3  ...     Trauma  Emergency        1 days 15:17:10 2174-09-29 12:09:00
# 4  ...    Medical      Other        1 days 15:14:48 2162-06-21 05:38:00
# 5  ...    Medical      Other        1 days 15:14:48 2162-06-21 05:38:00
# 6  ...    Medical      Other        1 days 15:14:48 2162-06-21 05:38:00
# 7  ...    Medical      Other        1 days 15:14:48 2162-06-21 05:38:00
# 8  ...    Medical  Emergency 2 days 11:29:35.999999 2136-01-14 17:23:32
# 9  ...    Medical  Emergency 2 days 11:29:35.999999 2136-01-14 17:23:32
#
#               outtime  death_time_from_intime  icu_mortality death_abs_time  \
# 0 2174-10-01 03:26:10                     NaT              0            NaT
# 1 2174-10-01 03:26:10                     NaT              0            NaT
# 2 2174-10-01 03:26:10                     NaT              0            NaT
# 3 2174-10-01 03:26:10                     NaT              0            NaT
# 4 2162-06-22 20:52:48      1363 days 18:22:00              0     2166-03-16
# 5 2162-06-22 20:52:48      1363 days 18:22:00              0     2166-03-16
# 6 2162-06-22 20:52:48      1363 days 18:22:00              0     2166-03-16
# 7 2162-06-22 20:52:48      1363 days 18:22:00              0     2166-03-16
# 8 2136-01-17 04:53:08        37 days 06:36:28              0     2136-02-21
# 9 2136-01-17 04:53:08        37 days 06:36:28              0     2136-02-21
#
#   icu_mortality_derived  t
# 0                 False  0
# 1                 False  1
# 2                 False  2
# 3                 False  3
# 4                 False  0
# 5                 False  1
# 6                 False  2
# 7                 False  3
# 8                 False  0
# 9                 False  1
#
# [10 rows x 35 columns]

# %%
sf_mimicdata.iloc[0]
# Out:
# stay_id                                                      mimic4-30000153
# grid_end                                                     0 days 12:00:00
# vent_mode__hours_since_last__last_12h                               6.983333
# temperature__mean__last_12h                                           37.625
# heart_rate__mean__last_12h                                         109.07692
# arterial_blood_pressure_mean__mean__last_12h                       84.380959
# fluid_out_urine__mean__last_12h                                    82.222221
# pco2_arterial__mean__last_12h                                           44.0
# respiratory_rate_measured__mean__last_12h                           17.23077
# o2_saturation__mean__last_12h                                       97.92308
# po2_arterial__mean__last_12h                                           233.0
# bicarbonate_arterial__last__last_12h                                     NaN
# activated_partial_thromboplastin_time__last__last_12h                    NaN
# hemoglobin__last__last_12h                                               NaN
# creatinine__last__last_12h                                               NaN
# ureum__last__last_12h                                                    NaN
# lactate__last__last_12h                                                  NaN
# glasgow_coma_scale_total__last__last_12h                       mild_impaired
# fio2__last__last_12h                                                   31_40
# vent_mode__last__last_12h                                            unknown
# subject_id                                                          12466550
# raw_age                                                                 61.0
# sex                                                                      1.0
# raw_height                                                               NaN
# raw_weight                                                              73.0
# unit_type                                                             Trauma
# origin                                                             Emergency
# los                                                          1 days 15:17:10
# intime                                                   2174-09-29 12:09:00
# outtime                                                  2174-10-01 03:26:10
# death_time_from_intime                                                   NaT
# icu_mortality                                                              0
# death_abs_time                                                           NaT
# icu_mortality_derived                                                  False
# t                                                                          0
# Name: 0, dtype: object

# %% [markdown]
# # Check if there are any stays with both icu_mortality=True and mortality_after_discharge=True

# %% [raw]
# #ratio of mortality
# last_rows = sf_mimicdata.groupby("stay_id").tail(1)
# (last_rows["mortality_after_discharge"] == 1).mean()

# %% [raw]
# conflicting_stays = sf_mimicdata.loc[
#     (sf_mimicdata["icu_mortality_derived"] == 1) &
#     (sf_mimicdata["mortality_after_discharge"] == 1),
#     "stay_id"
# ].unique()

# %% [raw]
# len(conflicting_stays)

# %%
sf_mimicdata = sf_mimicdata.rename(columns={"icu_mortality": "icu_mortality_flag", "icu_mortality_derived": "icu_mortality"})

# %%
sf_mimicdata.columns
# Out:
# Index(['stay_id', 'grid_end', 'vent_mode__hours_since_last__last_12h',
#        'temperature__mean__last_12h', 'heart_rate__mean__last_12h',
#        'arterial_blood_pressure_mean__mean__last_12h',
#        'fluid_out_urine__mean__last_12h', 'pco2_arterial__mean__last_12h',
#        'respiratory_rate_measured__mean__last_12h',
#        'o2_saturation__mean__last_12h', 'po2_arterial__mean__last_12h',
#        'bicarbonate_arterial__last__last_12h',
#        'activated_partial_thromboplastin_time__last__last_12h',
#        'hemoglobin__last__last_12h', 'creatinine__last__last_12h',
#        'ureum__last__last_12h', 'lactate__last__last_12h',
#        'glasgow_coma_scale_total__last__last_12h', 'fio2__last__last_12h',
#        'vent_mode__last__last_12h', 'subject_id', 'raw_age', 'sex',
#        'raw_height', 'raw_weight', 'unit_type', 'origin', 'los', 'intime',
#        'outtime', 'death_time_from_intime', 'icu_mortality_flag',
#        'death_abs_time', 'icu_mortality', 't'],
#       dtype='object')

# %%
#ratio of mortality
last_rows = sf_mimicdata.groupby("stay_id").tail(1)
(last_rows["icu_mortality"] == 1).mean()
# Out:
# np.float64(0.07408539812081799)

# %% [raw]
# #ratio of mortality
# last_rows = sf_mimicdata.groupby("stay_id").tail(1)
# (last_rows["mortality_after_discharge"] == 1).mean()

# %%
sf_mimicdata.stay_id.nunique()
# Out:
# 85037

# %%
sf_mimicdata = sf_mimicdata.sort_values(by=['stay_id', 't'])

# %% [markdown]
# # Checking: (Recorded) discharge timestamp is close to (<=5hrs) to observation timestamp
# ### Remove last row if time difference is less than or equal to 5 hours

# %% [raw]
# # Parameters
# BUCKET_HOURS = 12
# DECISION_HORIZON_HOURS = 5  # drop rows whose bucket-end is within 5h of ICU discharge
#
# # Ensure datetimes
# intime  = pd.to_datetime(sf_mimicdata["intime"],  errors="coerce")
# outtime = pd.to_datetime(sf_mimicdata["outtime"], errors="coerce")
#
# # Reference timestamp for each row = end of the bucket:
# # t=0 -> 12h, t=1 -> 24h, etc.
# ref_time = intime + pd.to_timedelta((sf_mimicdata["t"] + 1) * BUCKET_HOURS, unit="h")
# sf_mimicdata["ref_time"] = ref_time
#
# # Time remaining until discharge (can be negative if ref_time > outtime)
# time_to_discharge = outtime - ref_time
#
# # Keep rows where:
# #  - outtime is missing (can't evaluate; keep), OR
# #  - more than DECISION_HORIZON_HOURS remain until discharge
# mask_keep = time_to_discharge.isna() | (
#     time_to_discharge > pd.Timedelta(hours=DECISION_HORIZON_HOURS)
# )
#
# # (Optional) quick audit before dropping
# dropped = (~mask_keep).sum()
# kept = mask_keep.sum()
# print(f"Filtering by {DECISION_HORIZON_HOURS}h decision horizon: drop {dropped} rows, keep {kept} rows.")
#
# # Apply filter
# sf_mimicdata = sf_mimicdata[mask_keep].reset_index(drop=True)

# %%
sf_mimicdata.stay_id.nunique()
# Out:
# 85037

# %% [markdown]
# ## Mortality within X (3 months) days after discharge

# %%
# Ensure correct dtypes
sf_mimicdata["intime"]  = pd.to_datetime(sf_mimicdata["intime"], errors="coerce")
sf_mimicdata["outtime"] = pd.to_datetime(sf_mimicdata["outtime"], errors="coerce")

# death_time_from_intime must be timedelta
sf_mimicdata["death_time_from_intime"] = pd.to_timedelta(
    sf_mimicdata["death_time_from_intime"], errors="coerce"
)

# Absolute death time = intime + death offset
sf_mimicdata["death_abs_time"] = sf_mimicdata["intime"] + sf_mimicdata["death_time_from_intime"]

# Post-discharge mortality [outtime < death_abs_time ≤ (intime+12h)+90d]
sf_mimicdata["mortality_after_discharge_30d"] = (
    sf_mimicdata["death_abs_time"].notna()
    & (sf_mimicdata["death_abs_time"] > sf_mimicdata["outtime"])
    & (sf_mimicdata["death_abs_time"] <= (sf_mimicdata["intime"] + pd.Timedelta(hours=12) + pd.Timedelta(days=30)))
).astype(int)

# %%
#ratio of mortality
last_rows = sf_mimicdata.groupby("stay_id").tail(1)
(last_rows["mortality_after_discharge_30d"] == 1).mean()
# Out:
# np.float64(0.07483801168902948)

# %% [markdown]
# # Add A, Y and D

# %%
# Defaults: ongoing rows (A=0, D=0) -> Z and Y is missing. Therefore, nan
sf_mimicdata.loc[:, 'A'] = 0
sf_mimicdata.loc[:, 'D'] = 0
sf_mimicdata.loc[:, 'Z'] = np.nan
sf_mimicdata.loc[:, 'Y'] = np.nan

# %%
# Ensure correct ordering within stay
sf_mimicdata = sf_mimicdata.sort_values(["stay_id", "t"]).copy()

# Fill A
# Update "A" to 0 if "icu_mortality" is True, and A=1 in other case (~ icu_mortality) at the last row of each 'stay_id'
sf_mimicdata.loc[sf_mimicdata.groupby('stay_id').tail(1).index, 'A'] = sf_mimicdata.groupby('stay_id').tail(1)['icu_mortality'].apply(lambda x: 0 if x else 1)

# indices of terminal (last) row per stay
last_idx = sf_mimicdata.groupby("stay_id", sort=False).tail(1).index

# set D on terminal row from icu_mortality (True/False -> 1/0)
sf_mimicdata.loc[last_idx, "D"] = sf_mimicdata.loc[last_idx, "icu_mortality"].astype(int)

# terminal reason 1: in-ICU death (A=0, D=1) -> Y = 1
death_mask = sf_mimicdata.loc[last_idx, "D"].eq(1)
sf_mimicdata.loc[last_idx[death_mask], "Y"] = 1

# Fill Z
disch_mask = sf_mimicdata.loc[last_idx, "A"].eq(1) & sf_mimicdata.loc[last_idx, "D"].eq(0)
sf_mimicdata.loc[last_idx[disch_mask], "Z"] = sf_mimicdata.loc[last_idx[disch_mask], "mortality_after_discharge_30d"]
sf_mimicdata.loc[last_idx[disch_mask], "D"] = np.nan # To declare in-icu death as NA for discharged stays.

# Y will be filled below after truncation of stays for 90 days with Z

# %% [markdown]
# # Limit the study to 30 days since admission.
# # For stay_ids which have LOS lesser than 30days since admission, keep them as is.
# # For stays which are more than 30 days since admission, chop the rows to have LOS at 30 days only and declare those stays to have D=0, Z=0, Y=0 at the last row

# %%
def truncate_followup_30d_t(
    df,
    id_col="stay_id",
    t_col="t",
    intime_col="intime",
    outcome_cols=("A", "D", "Z", "Y"),
    bin_hours=12,
    death_td_col="death_time_from_intime"
):
    """
    Truncate longitudinal ICU data at K = 30 days since (intime + 12h) on a bin_hours grid.

    For stays exceeding K:
      - keep rows with t <= t_cutoff
      - at t == t_cutoff: set D=0, Y=0 (admin censoring)
      - at t == t_cutoff: set Z=NaN (post-discharge outcome undefined because not discharged by K)

    Parameters
    ----------
    df : pandas.DataFrame
        Long-format data with one row per (stay_id, t).
    id_col : str
        Stay identifier column.
    t_col : str
        Discrete time index column.
    intime_col : str
        ICU admission timestamp column.
    outcome_cols : tuple
        Outcome columns to zero at administrative cutoff.
    bin_hours : int
        Width of each discrete time interval (default 12h).

    Returns
    -------
    pandas.DataFrame
        Truncated dataframe.
    """

    df = df.copy()

    # Ensure proper types
    df[intime_col] = pd.to_datetime(df[intime_col], errors="coerce")

    # Ensure outcomes exist
    for c in outcome_cols:
        if c not in df.columns:
            df[c] = np.nan

    # Sort for consistency
    df = df.sort_values([id_col, t_col]).reset_index(drop=True)

    # --- cutoff at 30d since (intime + bin_hours) ---
    cutoff_time = df[intime_col] + pd.DateOffset(days=30) + pd.Timedelta(hours=bin_hours)

    # Convert cutoff_time → max allowed t
    delta_hours = (cutoff_time - df[intime_col]).dt.total_seconds() / 3600.0
    t_cutoff = np.floor(delta_hours / bin_hours).astype(int) - 1  # -> xx when bin_hours=12

    # Constant per stay
    df["_t_cutoff"] = df.groupby(id_col)[t_col].transform(
        lambda x: t_cutoff.loc[x.index].min()
    )

    # Identify long stays
    max_t = df.groupby(id_col)[t_col].transform("max")
    df["_long"] = max_t > df["_t_cutoff"]

    # Keep rows within cutoff
    kept = df[(~df["_long"]) | (df[t_col] <= df["_t_cutoff"])].copy()

    # For truncated stays, handle outcomes at final kept row
    mask_last = kept["_long"] & (kept[t_col] == kept["_t_cutoff"])

    # Admin censoring for time-local outcomes (D, Y, etc.), but NOT Z
    cols_to_zero = [c for c in outcome_cols if c not in ("Z",)]
    if cols_to_zero:
        kept.loc[mask_last, cols_to_zero] = 0

    # Post-discharge outcome undefined if not discharged by K
    if "Z" in outcome_cols:
        kept.loc[mask_last, "Z"] = np.nan
        kept.loc[mask_last, "Y"] = 0

    # Cleanup
    kept = kept.drop(columns=["_t_cutoff", "_long"], errors="ignore")
    kept = kept.sort_values([id_col, t_col]).reset_index(drop=True)

    return kept

# %%
sf_mimicdata_90d = truncate_followup_30d_t(sf_mimicdata)

# terminal row per stay *after truncation*
last_idx_90d = sf_mimicdata_90d.groupby("stay_id", sort=False).tail(1).index

# 1) In-ICU death at terminal row: (A=0, D=1) -> Y=1, Z must be NaN
icu_death = sf_mimicdata_90d.loc[last_idx_90d, "A"].eq(0) & sf_mimicdata_90d.loc[last_idx_90d, "D"].eq(1)
sf_mimicdata_90d.loc[last_idx_90d[icu_death], "Y"] = 1
sf_mimicdata_90d.loc[last_idx_90d[icu_death], "Z"] = np.nan

# 2) Discharged terminal row: (A=1, D=NA) -> Y = Z (0/1)
discharged = sf_mimicdata_90d.loc[last_idx_90d, "A"].eq(1) & sf_mimicdata_90d.loc[last_idx_90d, "D"].isna()
sf_mimicdata_90d.loc[last_idx_90d[discharged], "Y"] = sf_mimicdata_90d.loc[last_idx_90d[discharged], "Z"]

# 3) Admin censored in ICU at K: (A=0, D=0, Z=NaN) -> Y=0
censored = sf_mimicdata_90d.loc[last_idx_90d, "A"].eq(0) & sf_mimicdata_90d.loc[last_idx_90d, "D"].eq(0)
sf_mimicdata_90d.loc[last_idx_90d[censored], "Y"] = 0
sf_mimicdata_90d.loc[last_idx_90d[censored], "Z"] = np.nan

# %%
sf_mimicdata_90d.groupby('stay_id')['D'].max().mean()
# Out:
# np.float64(0.07245081552735867)

# %%
sf_mimicdata_90d.groupby('stay_id')['Z'].max().mean()
# Out:
# np.float64(0.08135714559656367)

# %%
sf_mimicdata_90d.groupby('stay_id')['Y'].max().mean()
# Out:
# np.float64(0.14728882721638817)

# %%
0.07376876911939845 + 0.14012706736587333
# Out:
# 0.21389583648527177

# %%
sf_mimicdata_90d.groupby(['A', 'D', 'Z', 'Y'], dropna=False).size().reset_index(name='count')
# Out:
#    A    D    Z    Y   count
# 0  0  0.0  NaN  0.0     653
# 1  0  0.0  NaN  NaN  616042
# 2  0  1.0  NaN  1.0    6161
# 3  1  NaN  0.0  0.0   71859
# 4  1  NaN  1.0  1.0    6364

# %%
last_rows = (
    sf_mimicdata_90d
    .sort_values(['stay_id', 't'])
    .groupby('stay_id')
    .tail(1)
)

# %%
last_rows[['A', 'D', 'Z', 'Y']].drop_duplicates().reset_index(drop=True)
# Out:
#    A    D    Z    Y
# 0  1  NaN  0.0  0.0
# 1  1  NaN  1.0  1.0
# 2  0  1.0  NaN  1.0
# 3  0  0.0  NaN  0.0

# %%
sf_mimicdata_90d.to_parquet('../Dataset/mimic-iv/from_pipeline/ltm_grided_clipped_A_D_Z_Y_SelfPipeline.parquet')

# %%
sf_mimicdata_90d.columns
# Out:
# Index(['stay_id', 'grid_end', 'vent_mode__hours_since_last__last_12h',
#        'temperature__mean__last_12h', 'heart_rate__mean__last_12h',
#        'arterial_blood_pressure_mean__mean__last_12h',
#        'fluid_out_urine__mean__last_12h', 'pco2_arterial__mean__last_12h',
#        'respiratory_rate_measured__mean__last_12h',
#        'o2_saturation__mean__last_12h', 'po2_arterial__mean__last_12h',
#        'bicarbonate_arterial__last__last_12h',
#        'activated_partial_thromboplastin_time__last__last_12h',
#        'hemoglobin__last__last_12h', 'creatinine__last__last_12h',
#        'ureum__last__last_12h', 'lactate__last__last_12h',
#        'glasgow_coma_scale_total__last__last_12h', 'fio2__last__last_12h',
#        'vent_mode__last__last_12h', 'subject_id', 'raw_age', 'sex',
#        'raw_height', 'raw_weight', 'unit_type', 'origin', 'los', 'intime',
#        'outtime', 'death_time_from_intime', 'icu_mortality_flag',
#        'death_abs_time', 'icu_mortality', 't', 'mortality_after_discharge_30d',
#        'A', 'D', 'Z', 'Y'],
#       dtype='object')

# %% [markdown]
# # Cross-checking that A, Y and D are behaving well

# %%
sf_mimicdata_90d.loc[sf_mimicdata_90d.Z==1].stay_id.unique()
# Out:
# array(['mimic4-30000646', 'mimic4-30004232', 'mimic4-30007228', ...,
#        'mimic4-39993425', 'mimic4-39995141', 'mimic4-39999168'],
#       shape=(6364,), dtype=object)

# %%
sf_mimicdata_90d.loc[sf_mimicdata_90d.stay_id=="mimic4-30000484"]
# Out:
#             stay_id        grid_end  vent_mode__hours_since_last__last_12h  \
# 8   mimic4-30000484 0 days 12:00:00                                    NaN
# 9   mimic4-30000484 1 days 00:00:00                                    NaN
# 10  mimic4-30000484 1 days 12:00:00                                    NaN
# 11  mimic4-30000484 2 days 00:00:00                                    NaN
# 12  mimic4-30000484 2 days 12:00:00                                    NaN
#
#     temperature__mean__last_12h  heart_rate__mean__last_12h  \
# 8                     35.629631                   89.166664
# 9                     36.125000                   90.750000
# 10                    36.759258                   94.833336
# 11                    36.222225                   91.500000
# 12                    36.611115                   93.000000
#
#     arterial_blood_pressure_mean__mean__last_12h  \
# 8                                      64.750000
# 9                                      69.487183
# 10                                     79.416664
# 11                                     77.000000
# 12                                     83.952377
#
#     fluid_out_urine__mean__last_12h  pco2_arterial__mean__last_12h  \
# 8                        114.000000                           59.0
# 9                         71.111115                            NaN
# 10                        86.666664                            NaN
# 11                        50.000000                            NaN
# 12                        58.750000                            NaN
#
#     respiratory_rate_measured__mean__last_12h  o2_saturation__mean__last_12h  \
# 8                                   15.000000                      99.750000
# 9                                   14.416667                      99.833336
# 10                                  19.750000                     100.000000
# 11                                  18.750000                     100.000000
# 12                                  20.333334                      99.666664
#
#     ...  death_time_from_intime  icu_mortality_flag  death_abs_time  \
# 8   ...        37 days 06:36:28                   0      2136-02-21
# 9   ...        37 days 06:36:28                   0      2136-02-21
# 10  ...        37 days 06:36:28                   0      2136-02-21
# 11  ...        37 days 06:36:28                   0      2136-02-21
# 12  ...        37 days 06:36:28                   0      2136-02-21
#
#     icu_mortality  t  mortality_after_discharge_30d  A    D    Z    Y
# 8           False  0                              0  0  0.0  NaN  NaN
# 9           False  1                              0  0  0.0  NaN  NaN
# 10          False  2                              0  0  0.0  NaN  NaN
# 11          False  3                              0  0  0.0  NaN  NaN
# 12          False  4                              0  1  NaN  0.0  0.0
#
# [5 rows x 40 columns]

# %%
sf_mimicdata_90d.t.max()
# Out:
# np.int64(60)

# %%
sf_mimicdata_90d.grid_end.max()
# Out:
# Timedelta('30 days 12:00:00')
